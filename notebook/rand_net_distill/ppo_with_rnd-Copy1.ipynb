# %%
from collections import deque
from copy import deepcopy

import gym
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions import Categorical
from torch.utils.data import DataLoader

# %%
SEED = 1
BATCH_SIZE = 4
LR = 0.0001
EPOCHS = 4
CLIP = 0.1
GAMMA = 0.99
LAMBDA = 0.95
ENT_COEF = 0.01
EX_COEF = 2.0
IN_COEF = 1.0

# set device
use_cuda = torch.cuda.is_available()
print('cuda:', use_cuda)
device = torch.device('cuda' if use_cuda else 'cpu')

# random seed
np.random.seed(SEED)
torch.manual_seed(SEED)
if use_cuda:
    torch.cuda.manual_seed_all(SEED)
# Out:
# cuda: True

# %%
class ActorCriticNet(nn.Module):
    def __init__(self, obs_space, action_space):
        super().__init__()

        self.head = nn.Sequential(
            nn.Linear(obs_space, 256),
            nn.SELU()
        )

        self.pol = nn.Sequential(
            nn.Linear(256, 256),
            nn.SELU(),
            nn.Linear(256, action_space)
        )
        
        self.val_ex = nn.Sequential(
            nn.Linear(256, 256),
            nn.SELU(),
            nn.Linear(256, 1)
        )
        
        self.val_in = nn.Sequential(
            nn.Linear(256, 256),
            nn.SELU(),
            nn.Linear(256, 1)
        )
        
        self.log_softmax = nn.LogSoftmax(dim=-1)

    def forward(self, x):
        out = self.head(x)
        logit = self.pol(out).reshape(out.shape[0], -1)
        value_ex = self.val_ex(out).reshape(out.shape[0], 1)
        value_in = self.val_in(out).reshape(out.shape[0], 1)
        log_probs = self.log_softmax(logit)
        
        return log_probs, value_ex, value_in
    
class RandomNet(nn.Module):
    def __init__(self, obs_space):
        super().__init__()
        self.head = nn.Sequential(
            nn.Linear(obs_space, 256),
            nn.SELU()
        )

        self.fc = nn.Sequential(
            nn.Linear(256, 512)
        )

    def forward(self, x):
        out = self.head(x)
        obs_feature = self.fc(out).reshape(out.shape[0], -1)

        return obs_feature


class PredictNet(nn.Module):
    def __init__(self, obs_space):
        super().__init__()
        self.head = nn.Sequential(
            nn.Linear(obs_space, 256),
            nn.SELU()
        )

        self.fc = nn.Sequential(
            nn.Linear(256, 256),
            nn.SELU(),
            nn.Linear(256, 256),
            nn.SELU(),
            nn.Linear(256, 512)
        )

    def forward(self, x):
        out = self.head(x)
        obs_feature = self.fc(out).reshape(out.shape[0], -1)

        return obs_feature

# %%
losses = []
m_losses = []
f_losses = []


def learn(net, old_net, pred_net, rand_net, net_optim, pred_optim, train_memory):
    global action_space

    net.train()
    old_net.train()
    dataloader = DataLoader(train_memory,
                        batch_size=BATCH_SIZE,
                        shuffle=True,
                        pin_memory=use_cuda)
    for i in range(EPOCHS):
        for (s, a, r_ex, r_in, _s, d, adv) in dataloader:
            s_batch = s.to(device).float()
            a_batch = a.detach().to(device).long()
            _s_batch = _s.to(device).float()
            _s_norm = normalize_obs(_s.detach().cpu().numpy())
            _s_norm_batch = torch.tensor(_s_norm).to(device).float()
            r_ex_batch = r_ex.to(device).float()
            r_in_batch = r_in.to(device).float()
            adv_batch = adv.to(device).float()
            done_mask = 1. - d.to(device).float()

            with torch.no_grad():
                rand_feature = rand_net(_s_norm_batch)
                log_p_batch_old, _, _ = old_net(s_batch)
                log_p_acting_old = log_p_batch_old[range(BATCH_SIZE), a_batch]

            pred_feature = pred_net(_s_norm_batch)
            log_p_batch, v_ex, v_in = net(s_batch)
            _, _v_ex, _v_in = net(_s_batch)
            log_p_acting = log_p_batch[range(BATCH_SIZE), a_batch]
            p_ratio = (log_p_acting - log_p_acting_old).exp()
            p_ratio_clip = torch.clamp(p_ratio, 1. - CLIP, 1. + CLIP)
            clip_loss = torch.min(p_ratio * adv_batch,
                                  p_ratio_clip * adv_batch)
            
            v_ex_loss = 0.5 * (r_ex_batch + GAMMA * done_mask * _v_ex - v_ex).pow(2)
            v_in_loss = 0.5 * (r_in_batch + GAMMA * done_mask * _v_in - v_in).pow(2)
            v_loss = v_ex_loss + v_in_loss 
            entropy = -(log_p_batch.exp() * log_p_batch).sum(dim=1)

            # loss
            m_loss = -(clip_loss - v_loss + ENT_COEF * entropy).mean()
            m_losses.append(m_loss)

            f_loss = (pred_feature - rand_feature).pow(2).sum(dim=1).mean()
            f_losses.append(f_loss)
            
            loss = m_loss + f_loss
            losses.append(loss)
            
            net_optim.zero_grad()
            pred_optim.zero_grad()
            loss.backward()
            net_optim.step()
            pred_optim.step()


def get_action_and_value(obs, old_net):
    old_net.eval()
    with torch.no_grad():
        state = torch.tensor([obs]).to(device).float()
        log_p, v_ex, v_in = old_net(state)
        m = Categorical(log_p.exp())
        action = m.sample()

    return action.item(), v_ex.item(), v_in.item()


def compute_adv(rewards, values, dones, roll_memory):
    rew = np.array(rewards, 'float')
    val = np.array(values[:-1], 'float')
    _val = np.array(values[1:], 'float')
    done_mask = 1. - np.array(dones, 'float')
    delta = rew + 0.99 * done_mask * _val - val
    disc_dt = np.array([
        (GAMMA * LAMBDA)**(i) * dt for i, dt in enumerate(delta.tolist())],
        'float')
    for i, data in enumerate(roll_memory):
        data.append(sum(disc_dt[i:] / (GAMMA * LAMBDA)**(i)))

    return roll_memory


def get_norm_params(obs_memory):
    global obs_apace

    obses = [[] for _ in range(obs_space)]
    for obs in obs_memory:
        for j in range(obs_space):
            obses[j].append(obs[j])

    mean = np.zeros(obs_space, 'float')
    std = np.zeros(obs_space, 'float')
    for i, obs_ in enumerate(obses):
        mean[i] = np.mean(obs_)
        std[i] = np.std(obs_)

    return mean, std


def normalize_obs(obs):
    global mean, std
#     means = [mean for _ in range(BATCH_SIZE)]
#     stds = [std for _ in range(BATCH_SIZE)]
#     mean_np = np.stack(means)
#     std_np = np.stack(stds)
    norm_obs = (obs - mean) / std

#     return np.clip(norm_obs, -5, 5)
    return norm_obs


def calculate_reward_in(pred_net, rand_net, obs):
    norm_obs = normalize_obs(obs)
    state = torch.tensor([norm_obs]).to(device).float()
    with torch.no_grad():
        pred_obs = pred_net(state)
        rand_obs = rand_net(state)
        reward = (pred_obs - rand_obs).pow(2).sum()
        clipped_reward = torch.clamp(reward, -1, 1)

    return clipped_reward.item()

# %% [markdown]
# ## Main

# %%
# make an environment
# env = gym.make('CartPole-v0')
env = gym.make('CartPole-v1')
# env = gym.make('MountainCar-v0')
# env = gym.make('LunarLander-v2')

env.seed(SEED)
obs_space = env.observation_space.shape[0]
action_space = env.action_space.n

# hyperparameter
n_episodes = 3000
roll_len = 128
n_eval = env.spec.trials

# global values
init_steps = 0
steps = 0
learn_steps = 0
mean = 0.
std = 0.
ep_rewards = []
is_rollout = False
is_solved = False
is_init_roll = True

# make nerual networks
net = ActorCriticNet(obs_space, action_space).to(device)
old_net = deepcopy(net)
pred_net = PredictNet(obs_space).to(device)
rand_net = RandomNet(obs_space).to(device)

# make optimizer
net_optim = torch.optim.Adam(net.parameters(), lr=LR, eps=1e-5)
pred_optim = torch.optim.Adam(pred_net.parameters(), lr=LR, eps=1e-5)

# make a rollout memory
train_memory = []
roll_memory = []
obs_memory = []
rewards = []
values = []
dones = []

# %%
use_cuda
# Out:
# True

# %%
env.spec.max_episode_steps
# Out:
# 500

# %%
env.spec.trials
# Out:
# 100

# %%
env.spec.reward_threshold
# Out:
# 475.0

# %%
# simulation
while True:
    obs = env.reset()
    done = False
    while not done:
#         env.render()
        action = env.action_space.sample()
        _obs, _, done, _ = env.step(action)
        obs_memory.append(_obs)
        obs = _obs
        init_steps += 1
        if init_steps == roll_len * 50:
            mean, std = get_norm_params(obs_memory)
            obs_memory.clear()
            is_init_roll = False
            break
    if not is_init_roll:
        break

# %%
# play!
for i in range(1, n_episodes + 1):
    obs = env.reset()
    done = False
    ep_reward_ex = 0.
    ep_reward_in = 0.
    while not done:
#         env.render()

        action, val_ex, val_in = get_action_and_value(obs, old_net)
        _obs, rew_ex, done, _ = env.step(action)
        
        rew_in = calculate_reward_in(pred_net, rand_net, _obs)    
        
        reward = EX_COEF * rew_ex + IN_COEF * rew_in
        value = val_ex + val_in
        
        # store
        roll_memory.append([obs, action, EX_COEF * rew_ex, IN_COEF * rew_in, _obs, done])
        obs_memory.append(_obs)
        rewards.append(reward)
        values.append(value)
        dones.append(done)
        
        obs = _obs
        steps += 1
        ep_reward_ex += rew_ex
        ep_reward_in += rew_in
        
        if done or steps % roll_len == 0:
            _, _val_ex, _val_in = get_action_and_value(_obs, old_net)
            _value = _val_ex + _val_in
            values.append(_value)
            train_memory.extend(compute_adv(rewards, values, dones, roll_memory))
            rewards.clear()
            values.clear()
            dones.clear()
            roll_memory.clear()
            
        if steps % roll_len == 0:
#             print('\n============  Start Learning  ============\n')
            learn(net, old_net, pred_net, rand_net, net_optim, pred_optim, train_memory)
            learn_steps += 1
            train_memory.clear()

        if learn_steps > 1:
            old_net.load_state_dict(net.state_dict())
            learn_steps = 1
        
        if steps % roll_len*50 == 0:
            mean, std = get_norm_params(obs_memory)
            obs_memory.clear()
    
    if done:        
        ep_rewards.append(ep_reward_ex)
        print('{:3} Episode in {:5} steps, reward_ex {:.2f}, reward_in {:.2f}'.format(
            i, steps, ep_reward_ex, ep_reward_in))

        if len(ep_rewards) >= n_eval:
            if np.mean(list(reversed(ep_rewards))[: n_eval]) >= env.spec.reward_threshold:
                print('\n{} is sloved! {:3} Episode in {:3} steps'.format(
                    env.spec.id, i, steps))
                torch.save(old_net.state_dict(),
                           f'./test/saved_models/{env.spec.id}_ep{i}_clear_model_ppo.pt')
                break
env.close()
# Out:
#   1 Episode in    14 steps, reward_ex 14.00, reward_in 14.00
#   2 Episode in    35 steps, reward_ex 21.00, reward_in 21.00
#   3 Episode in    52 steps, reward_ex 17.00, reward_in 17.00
#   4 Episode in    70 steps, reward_ex 18.00, reward_in 18.00
#   5 Episode in   104 steps, reward_ex 34.00, reward_in 34.00
#   6 Episode in   120 steps, reward_ex 16.00, reward_in 16.00
#   7 Episode in   146 steps, reward_ex 26.00, reward_in 25.44
#   8 Episode in   167 steps, reward_ex 21.00, reward_in 21.00
#   9 Episode in   184 steps, reward_ex 17.00, reward_in 17.00
#  10 Episode in   202 steps, reward_ex 18.00, reward_in 17.84
#  11 Episode in   213 steps, reward_ex 11.00, reward_in 10.56
#  12 Episode in   240 steps, reward_ex 27.00, reward_in 25.95
#  13 Episode in   260 steps, reward_ex 20.00, reward_in 19.93
#  14 Episode in   275 steps, reward_ex 15.00, reward_in 13.08
#  15 Episode in   300 steps, reward_ex 25.00, reward_in 25.00
#  16 Episode in   347 steps, reward_ex 47.00, reward_in 47.00
#  17 Episode in   363 steps, reward_ex 16.00, reward_in 16.00
#  18 Episode in   388 steps, reward_ex 25.00, reward_in 25.00
#  19 Episode in   413 steps, reward_ex 25.00, reward_in 24.65
#  20 Episode in   496 steps, reward_ex 83.00, reward_in 83.00
#  21 Episode in   533 steps, reward_ex 37.00, reward_in 37.00
#  22 Episode in   600 steps, reward_ex 67.00, reward_in 67.00
#  23 Episode in   637 steps, reward_ex 37.00, reward_in 37.00
#  24 Episode in   687 steps, reward_ex 50.00, reward_in 50.00
#  25 Episode in   714 steps, reward_ex 27.00, reward_in 25.95
#  26 Episode in   795 steps, reward_ex 81.00, reward_in 78.73
#  27 Episode in   863 steps, reward_ex 68.00, reward_in 62.73
#  28 Episode in   906 steps, reward_ex 43.00, reward_in 42.10
#  29 Episode in   930 steps, reward_ex 24.00, reward_in 20.91
#  30 Episode in  1002 steps, reward_ex 72.00, reward_in 70.68
#  31 Episode in  1036 steps, reward_ex 34.00, reward_in 29.31
#  32 Episode in  1096 steps, reward_ex 60.00, reward_in 60.00
#  33 Episode in  1185 steps, reward_ex 89.00, reward_in 87.21
#  34 Episode in  1235 steps, reward_ex 50.00, reward_in 50.00
#  35 Episode in  1298 steps, reward_ex 63.00, reward_in 62.92
#  36 Episode in  1389 steps, reward_ex 91.00, reward_in 75.82
#  37 Episode in  1448 steps, reward_ex 59.00, reward_in 55.84
#  38 Episode in  1509 steps, reward_ex 61.00, reward_in 60.65
#  39 Episode in  1562 steps, reward_ex 53.00, reward_in 48.90
#  40 Episode in  1623 steps, reward_ex 61.00, reward_in 57.31
#  41 Episode in  1713 steps, reward_ex 90.00, reward_in 88.76
#  42 Episode in  1770 steps, reward_ex 57.00, reward_in 41.67
#  43 Episode in  1807 steps, reward_ex 37.00, reward_in 26.74
#  44 Episode in  1872 steps, reward_ex 65.00, reward_in 65.00
#  45 Episode in  1956 steps, reward_ex 84.00, reward_in 83.96
#  46 Episode in  2024 steps, reward_ex 68.00, reward_in 68.00
#  47 Episode in  2105 steps, reward_ex 81.00, reward_in 70.29
#  48 Episode in  2154 steps, reward_ex 49.00, reward_in 39.04
#  49 Episode in  2296 steps, reward_ex 142.00, reward_in 117.42
#  50 Episode in  2406 steps, reward_ex 110.00, reward_in 105.58
#  51 Episode in  2497 steps, reward_ex 91.00, reward_in 91.00
#  52 Episode in  2542 steps, reward_ex 45.00, reward_in 45.00
#  53 Episode in  2603 steps, reward_ex 61.00, reward_in 42.35
#  54 Episode in  2730 steps, reward_ex 127.00, reward_in 117.87
#  55 Episode in  2816 steps, reward_ex 86.00, reward_in 60.43
#  56 Episode in  2877 steps, reward_ex 61.00, reward_in 37.73
#  57 Episode in  2919 steps, reward_ex 42.00, reward_in 26.34
#  58 Episode in  3023 steps, reward_ex 104.00, reward_in 89.36
#  59 Episode in  3094 steps, reward_ex 71.00, reward_in 50.22
#  60 Episode in  3128 steps, reward_ex 34.00, reward_in 28.51
#  61 Episode in  3204 steps, reward_ex 76.00, reward_in 66.54
#  62 Episode in  3252 steps, reward_ex 48.00, reward_in 15.21
#  63 Episode in  3301 steps, reward_ex 49.00, reward_in 18.45
#  64 Episode in  3347 steps, reward_ex 46.00, reward_in 14.33
#  65 Episode in  3431 steps, reward_ex 84.00, reward_in 83.71
#  66 Episode in  3467 steps, reward_ex 36.00, reward_in 29.27
#  67 Episode in  3508 steps, reward_ex 41.00, reward_in 33.19
#  68 Episode in  3558 steps, reward_ex 50.00, reward_in 38.54
#  69 Episode in  3665 steps, reward_ex 107.00, reward_in 104.05
#  70 Episode in  3722 steps, reward_ex 57.00, reward_in 32.73
#  71 Episode in  3760 steps, reward_ex 38.00, reward_in 38.00
#  72 Episode in  3816 steps, reward_ex 56.00, reward_in 56.00
#  73 Episode in  3860 steps, reward_ex 44.00, reward_in 35.95
#  74 Episode in  3915 steps, reward_ex 55.00, reward_in 47.70
#  75 Episode in  3978 steps, reward_ex 63.00, reward_in 55.40
#  76 Episode in  4048 steps, reward_ex 70.00, reward_in 54.54
#  77 Episode in  4091 steps, reward_ex 43.00, reward_in 14.53
#  78 Episode in  4149 steps, reward_ex 58.00, reward_in 23.56
#  79 Episode in  4188 steps, reward_ex 39.00, reward_in 14.55
#  80 Episode in  4245 steps, reward_ex 57.00, reward_in 23.53
#  81 Episode in  4285 steps, reward_ex 40.00, reward_in 10.19
#  82 Episode in  4335 steps, reward_ex 50.00, reward_in 35.73
#  83 Episode in  4378 steps, reward_ex 43.00, reward_in 11.79
#  84 Episode in  4428 steps, reward_ex 50.00, reward_in 19.15
#  85 Episode in  4462 steps, reward_ex 34.00, reward_in 7.92
#  86 Episode in  4527 steps, reward_ex 65.00, reward_in 45.23
#  87 Episode in  4582 steps, reward_ex 55.00, reward_in 15.68
#  88 Episode in  4623 steps, reward_ex 41.00, reward_in 15.93
#  89 Episode in  4693 steps, reward_ex 70.00, reward_in 31.38
#  90 Episode in  4734 steps, reward_ex 41.00, reward_in 26.91
#  91 Episode in  4831 steps, reward_ex 97.00, reward_in 72.00
#  92 Episode in  4890 steps, reward_ex 59.00, reward_in 30.28
#  93 Episode in  4936 steps, reward_ex 46.00, reward_in 34.26
#  94 Episode in  4992 steps, reward_ex 56.00, reward_in 45.45
#  95 Episode in  5037 steps, reward_ex 45.00, reward_in 27.47
#  96 Episode in  5093 steps, reward_ex 56.00, reward_in 28.18
#  97 Episode in  5137 steps, reward_ex 44.00, reward_in 22.28
#  98 Episode in  5191 steps, reward_ex 54.00, reward_in 24.90
#  99 Episode in  5293 steps, reward_ex 102.00, reward_in 57.08
# 100 Episode in  5333 steps, reward_ex 40.00, reward_in 20.64
# 101 Episode in  5387 steps, reward_ex 54.00, reward_in 14.62
# 102 Episode in  5456 steps, reward_ex 69.00, reward_in 24.48
# 103 Episode in  5510 steps, reward_ex 54.00, reward_in 22.06
# 104 Episode in  5560 steps, reward_ex 50.00, reward_in 9.48
# 105 Episode in  5614 steps, reward_ex 54.00, reward_in 10.61
# 106 Episode in  5704 steps, reward_ex 90.00, reward_in 28.60
# 107 Episode in  5775 steps, reward_ex 71.00, reward_in 15.95
# 108 Episode in  5816 steps, reward_ex 41.00, reward_in 10.70
# 109 Episode in  5882 steps, reward_ex 66.00, reward_in 12.69
# 110 Episode in  5929 steps, reward_ex 47.00, reward_in 7.41
# 111 Episode in  6081 steps, reward_ex 152.00, reward_in 142.26
# 112 Episode in  6127 steps, reward_ex 46.00, reward_in 30.77
# 113 Episode in  6195 steps, reward_ex 68.00, reward_in 38.09
# 114 Episode in  6335 steps, reward_ex 140.00, reward_in 134.46
# 115 Episode in  6375 steps, reward_ex 40.00, reward_in 15.32
# 116 Episode in  6417 steps, reward_ex 42.00, reward_in 12.90
# 117 Episode in  6457 steps, reward_ex 40.00, reward_in 20.84
# 118 Episode in  6587 steps, reward_ex 130.00, reward_in 123.71
# 119 Episode in  6640 steps, reward_ex 53.00, reward_in 10.60
# 120 Episode in  6684 steps, reward_ex 44.00, reward_in 15.82
# 121 Episode in  6777 steps, reward_ex 93.00, reward_in 46.65
# 122 Episode in  6845 steps, reward_ex 68.00, reward_in 16.13
# 123 Episode in  6910 steps, reward_ex 65.00, reward_in 12.57
# 124 Episode in  6983 steps, reward_ex 73.00, reward_in 24.76
# 125 Episode in  7048 steps, reward_ex 65.00, reward_in 30.84
# 126 Episode in  7093 steps, reward_ex 45.00, reward_in 17.58
# 127 Episode in  7137 steps, reward_ex 44.00, reward_in 9.89
# 128 Episode in  7243 steps, reward_ex 106.00, reward_in 47.90
# 129 Episode in  7313 steps, reward_ex 70.00, reward_in 58.07
# 130 Episode in  7364 steps, reward_ex 51.00, reward_in 39.12
# 131 Episode in  7415 steps, reward_ex 51.00, reward_in 20.50
# 132 Episode in  7460 steps, reward_ex 45.00, reward_in 13.01
# 133 Episode in  7505 steps, reward_ex 45.00, reward_in 14.40
# 134 Episode in  7560 steps, reward_ex 55.00, reward_in 24.39
# 135 Episode in  7615 steps, reward_ex 55.00, reward_in 24.97
# 136 Episode in  7656 steps, reward_ex 41.00, reward_in 10.79
# 137 Episode in  7697 steps, reward_ex 41.00, reward_in 12.45
# 138 Episode in  7735 steps, reward_ex 38.00, reward_in 8.96
# 139 Episode in  7803 steps, reward_ex 68.00, reward_in 52.95
# 140 Episode in  7838 steps, reward_ex 35.00, reward_in 25.14
# 141 Episode in  7877 steps, reward_ex 39.00, reward_in 13.31
# 142 Episode in  7920 steps, reward_ex 43.00, reward_in 24.60
# 143 Episode in  7955 steps, reward_ex 35.00, reward_in 14.65
# 144 Episode in  7992 steps, reward_ex 37.00, reward_in 23.16
# 145 Episode in  8035 steps, reward_ex 43.00, reward_in 28.00
# 146 Episode in  8079 steps, reward_ex 44.00, reward_in 15.97
# 147 Episode in  8161 steps, reward_ex 82.00, reward_in 33.62
# 148 Episode in  8204 steps, reward_ex 43.00, reward_in 6.17
# 149 Episode in  8244 steps, reward_ex 40.00, reward_in 19.05
# 150 Episode in  8287 steps, reward_ex 43.00, reward_in 8.79
# 151 Episode in  8334 steps, reward_ex 47.00, reward_in 8.92
# 152 Episode in  8404 steps, reward_ex 70.00, reward_in 32.13
# 153 Episode in  8446 steps, reward_ex 42.00, reward_in 10.32
# 154 Episode in  8536 steps, reward_ex 90.00, reward_in 25.75
# 155 Episode in  8579 steps, reward_ex 43.00, reward_in 6.66
# 156 Episode in  8618 steps, reward_ex 39.00, reward_in 6.36
# 157 Episode in  8653 steps, reward_ex 35.00, reward_in 6.54
# 158 Episode in  8704 steps, reward_ex 51.00, reward_in 26.86
# 159 Episode in  8748 steps, reward_ex 44.00, reward_in 13.12
# 160 Episode in  8845 steps, reward_ex 97.00, reward_in 89.44
# 161 Episode in  8882 steps, reward_ex 37.00, reward_in 9.08
# 162 Episode in  8919 steps, reward_ex 37.00, reward_in 11.99
# 163 Episode in  8990 steps, reward_ex 71.00, reward_in 17.83
# 164 Episode in  9027 steps, reward_ex 37.00, reward_in 7.71
# 165 Episode in  9067 steps, reward_ex 40.00, reward_in 8.41
# 166 Episode in  9111 steps, reward_ex 44.00, reward_in 6.12
# 167 Episode in  9166 steps, reward_ex 55.00, reward_in 14.35
# 168 Episode in  9201 steps, reward_ex 35.00, reward_in 4.93
# 169 Episode in  9238 steps, reward_ex 37.00, reward_in 6.42
# 170 Episode in  9301 steps, reward_ex 63.00, reward_in 30.43
# 171 Episode in  9343 steps, reward_ex 42.00, reward_in 14.10
# 172 Episode in  9375 steps, reward_ex 32.00, reward_in 5.89
# 173 Episode in  9415 steps, reward_ex 40.00, reward_in 16.24
# 174 Episode in  9448 steps, reward_ex 33.00, reward_in 6.55
# 175 Episode in  9485 steps, reward_ex 37.00, reward_in 6.14
# 176 Episode in  9530 steps, reward_ex 45.00, reward_in 8.02
# 177 Episode in  9602 steps, reward_ex 72.00, reward_in 33.48
# 178 Episode in  9654 steps, reward_ex 52.00, reward_in 9.37
# 179 Episode in  9702 steps, reward_ex 48.00, reward_in 7.99
# 180 Episode in  9776 steps, reward_ex 74.00, reward_in 20.53
# 181 Episode in  9866 steps, reward_ex 90.00, reward_in 52.56
# 182 Episode in  9910 steps, reward_ex 44.00, reward_in 37.91
# 183 Episode in  9945 steps, reward_ex 35.00, reward_in 27.00
# 184 Episode in  9997 steps, reward_ex 52.00, reward_in 35.87
# 185 Episode in 10055 steps, reward_ex 58.00, reward_in 27.35
# 186 Episode in 10103 steps, reward_ex 48.00, reward_in 21.16
# 187 Episode in 10191 steps, reward_ex 88.00, reward_in 52.21
# 188 Episode in 10235 steps, reward_ex 44.00, reward_in 6.72
# 189 Episode in 10274 steps, reward_ex 39.00, reward_in 9.71
# 190 Episode in 10319 steps, reward_ex 45.00, reward_in 8.42
# 191 Episode in 10357 steps, reward_ex 38.00, reward_in 8.77
# 192 Episode in 10398 steps, reward_ex 41.00, reward_in 9.69
# 193 Episode in 10441 steps, reward_ex 43.00, reward_in 6.68
# 194 Episode in 10483 steps, reward_ex 42.00, reward_in 14.69
# 195 Episode in 10525 steps, reward_ex 42.00, reward_in 8.84
# 196 Episode in 10589 steps, reward_ex 64.00, reward_in 18.91
# 197 Episode in 10686 steps, reward_ex 97.00, reward_in 23.51
# 198 Episode in 10760 steps, reward_ex 74.00, reward_in 17.40
# 199 Episode in 10839 steps, reward_ex 79.00, reward_in 54.67
# 200 Episode in 10930 steps, reward_ex 91.00, reward_in 61.31
# 201 Episode in 10968 steps, reward_ex 38.00, reward_in 20.14
# 202 Episode in 11001 steps, reward_ex 33.00, reward_in 22.83
# 203 Episode in 11044 steps, reward_ex 43.00, reward_in 9.82
# 204 Episode in 11097 steps, reward_ex 53.00, reward_in 15.99
# 205 Episode in 11173 steps, reward_ex 76.00, reward_in 34.55
# 206 Episode in 11211 steps, reward_ex 38.00, reward_in 7.70
# 207 Episode in 11259 steps, reward_ex 48.00, reward_in 9.33
# 208 Episode in 11321 steps, reward_ex 62.00, reward_in 13.81
# 209 Episode in 11409 steps, reward_ex 88.00, reward_in 40.63
# 210 Episode in 11465 steps, reward_ex 56.00, reward_in 10.72
# 211 Episode in 11509 steps, reward_ex 44.00, reward_in 9.20
# 212 Episode in 11559 steps, reward_ex 50.00, reward_in 7.66
# 213 Episode in 11605 steps, reward_ex 46.00, reward_in 9.39
# 214 Episode in 11671 steps, reward_ex 66.00, reward_in 15.94
# 215 Episode in 11717 steps, reward_ex 46.00, reward_in 6.88
# 216 Episode in 11754 steps, reward_ex 37.00, reward_in 5.68
# 217 Episode in 11823 steps, reward_ex 69.00, reward_in 11.86
# 218 Episode in 11865 steps, reward_ex 42.00, reward_in 5.23
# 219 Episode in 11943 steps, reward_ex 78.00, reward_in 12.19
# 220 Episode in 11995 steps, reward_ex 52.00, reward_in 6.06
# 221 Episode in 12039 steps, reward_ex 44.00, reward_in 8.64
# 222 Episode in 12116 steps, reward_ex 77.00, reward_in 18.68
# 223 Episode in 12169 steps, reward_ex 53.00, reward_in 9.10
# 224 Episode in 12207 steps, reward_ex 38.00, reward_in 6.21
# 225 Episode in 12247 steps, reward_ex 40.00, reward_in 6.81
# 226 Episode in 12310 steps, reward_ex 63.00, reward_in 12.08
# 227 Episode in 12374 steps, reward_ex 64.00, reward_in 11.50
# 228 Episode in 12414 steps, reward_ex 40.00, reward_in 8.58
# 229 Episode in 12554 steps, reward_ex 140.00, reward_in 99.61
# 230 Episode in 12631 steps, reward_ex 77.00, reward_in 73.06
# 231 Episode in 12713 steps, reward_ex 82.00, reward_in 71.96
# 232 Episode in 12760 steps, reward_ex 47.00, reward_in 12.49
# 233 Episode in 12806 steps, reward_ex 46.00, reward_in 9.08
# 234 Episode in 12850 steps, reward_ex 44.00, reward_in 8.67
# 235 Episode in 12900 steps, reward_ex 50.00, reward_in 7.50
# 236 Episode in 12941 steps, reward_ex 41.00, reward_in 7.54
# 237 Episode in 12999 steps, reward_ex 58.00, reward_in 5.58
# 238 Episode in 13063 steps, reward_ex 64.00, reward_in 15.64
# 239 Episode in 13109 steps, reward_ex 46.00, reward_in 8.00
# 240 Episode in 13159 steps, reward_ex 50.00, reward_in 5.02
# 241 Episode in 13224 steps, reward_ex 65.00, reward_in 5.06
# 242 Episode in 13260 steps, reward_ex 36.00, reward_in 3.75
# 243 Episode in 13295 steps, reward_ex 35.00, reward_in 14.94
# 244 Episode in 13331 steps, reward_ex 36.00, reward_in 4.24
# 245 Episode in 13387 steps, reward_ex 56.00, reward_in 9.25
# 246 Episode in 13424 steps, reward_ex 37.00, reward_in 5.17
# 247 Episode in 13464 steps, reward_ex 40.00, reward_in 6.06
# 248 Episode in 13504 steps, reward_ex 40.00, reward_in 3.40
# 249 Episode in 13554 steps, reward_ex 50.00, reward_in 4.66
# 250 Episode in 13585 steps, reward_ex 31.00, reward_in 3.77
# 251 Episode in 13635 steps, reward_ex 50.00, reward_in 9.96
# 252 Episode in 13697 steps, reward_ex 62.00, reward_in 6.84
# 253 Episode in 13732 steps, reward_ex 35.00, reward_in 3.62
# 254 Episode in 13824 steps, reward_ex 92.00, reward_in 44.76
# 255 Episode in 13878 steps, reward_ex 54.00, reward_in 8.37
# 256 Episode in 13922 steps, reward_ex 44.00, reward_in 7.82
# 257 Episode in 13962 steps, reward_ex 40.00, reward_in 5.12
# 258 Episode in 14021 steps, reward_ex 59.00, reward_in 18.54
# 259 Episode in 14073 steps, reward_ex 52.00, reward_in 12.42
# 260 Episode in 14168 steps, reward_ex 95.00, reward_in 14.50
# 261 Episode in 14220 steps, reward_ex 52.00, reward_in 8.72
# 262 Episode in 14268 steps, reward_ex 48.00, reward_in 12.22
# 263 Episode in 14313 steps, reward_ex 45.00, reward_in 14.89
# 264 Episode in 14358 steps, reward_ex 45.00, reward_in 9.91
# 265 Episode in 14393 steps, reward_ex 35.00, reward_in 6.09
# 266 Episode in 14437 steps, reward_ex 44.00, reward_in 9.68
# 267 Episode in 14478 steps, reward_ex 41.00, reward_in 10.17
# 268 Episode in 14547 steps, reward_ex 69.00, reward_in 53.08
# 269 Episode in 14587 steps, reward_ex 40.00, reward_in 13.17
# 270 Episode in 14622 steps, reward_ex 35.00, reward_in 4.30
# 271 Episode in 14657 steps, reward_ex 35.00, reward_in 3.70
# 272 Episode in 14746 steps, reward_ex 89.00, reward_in 19.42
# 273 Episode in 14781 steps, reward_ex 35.00, reward_in 2.89
# 274 Episode in 14836 steps, reward_ex 55.00, reward_in 9.25
# 275 Episode in 14876 steps, reward_ex 40.00, reward_in 3.83
# 276 Episode in 14959 steps, reward_ex 83.00, reward_in 20.61
# 277 Episode in 15013 steps, reward_ex 54.00, reward_in 8.80
# 278 Episode in 15060 steps, reward_ex 47.00, reward_in 13.09
# 279 Episode in 15104 steps, reward_ex 44.00, reward_in 8.18
# 280 Episode in 15155 steps, reward_ex 51.00, reward_in 12.22
# 281 Episode in 15198 steps, reward_ex 43.00, reward_in 6.35
# 282 Episode in 15236 steps, reward_ex 38.00, reward_in 6.96
# 283 Episode in 15286 steps, reward_ex 50.00, reward_in 5.16
# 284 Episode in 15355 steps, reward_ex 69.00, reward_in 6.90
# 285 Episode in 15404 steps, reward_ex 49.00, reward_in 9.95
# 286 Episode in 15505 steps, reward_ex 101.00, reward_in 12.25
# 287 Episode in 15549 steps, reward_ex 44.00, reward_in 7.68
# 288 Episode in 15605 steps, reward_ex 56.00, reward_in 9.82
# 289 Episode in 15679 steps, reward_ex 74.00, reward_in 13.86
# 290 Episode in 15753 steps, reward_ex 74.00, reward_in 16.46
# 291 Episode in 15846 steps, reward_ex 93.00, reward_in 15.70
# 292 Episode in 15916 steps, reward_ex 70.00, reward_in 13.61
# 293 Episode in 15965 steps, reward_ex 49.00, reward_in 6.94
# 294 Episode in 16054 steps, reward_ex 89.00, reward_in 17.83
# 295 Episode in 16109 steps, reward_ex 55.00, reward_in 4.19
# 296 Episode in 16143 steps, reward_ex 34.00, reward_in 4.11
# 297 Episode in 16183 steps, reward_ex 40.00, reward_in 6.19
# 298 Episode in 16219 steps, reward_ex 36.00, reward_in 4.23
# 299 Episode in 16286 steps, reward_ex 67.00, reward_in 14.22
# 300 Episode in 16321 steps, reward_ex 35.00, reward_in 4.19
# 301 Episode in 16353 steps, reward_ex 32.00, reward_in 2.92
# 302 Episode in 16389 steps, reward_ex 36.00, reward_in 3.23
# 303 Episode in 16438 steps, reward_ex 49.00, reward_in 9.36
# 304 Episode in 16471 steps, reward_ex 33.00, reward_in 3.98
# 305 Episode in 16517 steps, reward_ex 46.00, reward_in 7.71
# 306 Episode in 16592 steps, reward_ex 75.00, reward_in 72.05
# 307 Episode in 16643 steps, reward_ex 51.00, reward_in 16.41
# 308 Episode in 16692 steps, reward_ex 49.00, reward_in 15.98
# 309 Episode in 16741 steps, reward_ex 49.00, reward_in 14.49
# 310 Episode in 16788 steps, reward_ex 47.00, reward_in 12.33
# 311 Episode in 16835 steps, reward_ex 47.00, reward_in 6.64
# 312 Episode in 16875 steps, reward_ex 40.00, reward_in 7.11
# 313 Episode in 16919 steps, reward_ex 44.00, reward_in 5.98
# 314 Episode in 16999 steps, reward_ex 80.00, reward_in 19.92
# 315 Episode in 17041 steps, reward_ex 42.00, reward_in 5.55
# 316 Episode in 17085 steps, reward_ex 44.00, reward_in 28.21
# 317 Episode in 17121 steps, reward_ex 36.00, reward_in 19.10
# 318 Episode in 17169 steps, reward_ex 48.00, reward_in 9.83
# 319 Episode in 17253 steps, reward_ex 84.00, reward_in 72.25
# 320 Episode in 17301 steps, reward_ex 48.00, reward_in 10.20
# 321 Episode in 17355 steps, reward_ex 54.00, reward_in 8.03
# 322 Episode in 17411 steps, reward_ex 56.00, reward_in 7.97
# 323 Episode in 17465 steps, reward_ex 54.00, reward_in 9.15
# 324 Episode in 17511 steps, reward_ex 46.00, reward_in 5.85
# 325 Episode in 17556 steps, reward_ex 45.00, reward_in 8.32
# 326 Episode in 17616 steps, reward_ex 60.00, reward_in 7.97
# 327 Episode in 17656 steps, reward_ex 40.00, reward_in 3.55
# 328 Episode in 17724 steps, reward_ex 68.00, reward_in 7.24
# 329 Episode in 17776 steps, reward_ex 52.00, reward_in 4.51
# 330 Episode in 17884 steps, reward_ex 108.00, reward_in 22.26
# 331 Episode in 17943 steps, reward_ex 59.00, reward_in 13.83
# 332 Episode in 18025 steps, reward_ex 82.00, reward_in 22.78
# 333 Episode in 18070 steps, reward_ex 45.00, reward_in 6.63
# 334 Episode in 18180 steps, reward_ex 110.00, reward_in 16.77
# 335 Episode in 18240 steps, reward_ex 60.00, reward_in 6.73
# 336 Episode in 18276 steps, reward_ex 36.00, reward_in 8.92
# 337 Episode in 18322 steps, reward_ex 46.00, reward_in 4.98
# 338 Episode in 18367 steps, reward_ex 45.00, reward_in 7.17
# 339 Episode in 18417 steps, reward_ex 50.00, reward_in 8.71
# 340 Episode in 18457 steps, reward_ex 40.00, reward_in 4.13
# 341 Episode in 18529 steps, reward_ex 72.00, reward_in 10.37
# 342 Episode in 18567 steps, reward_ex 38.00, reward_in 2.77
# 343 Episode in 18609 steps, reward_ex 42.00, reward_in 3.29
# 344 Episode in 18669 steps, reward_ex 60.00, reward_in 6.69
# 345 Episode in 18781 steps, reward_ex 112.00, reward_in 19.22
# 346 Episode in 18901 steps, reward_ex 120.00, reward_in 19.39
# 347 Episode in 18945 steps, reward_ex 44.00, reward_in 9.67
# 348 Episode in 18993 steps, reward_ex 48.00, reward_in 9.94
# 349 Episode in 19031 steps, reward_ex 38.00, reward_in 13.81
# 350 Episode in 19071 steps, reward_ex 40.00, reward_in 15.21
# 351 Episode in 19121 steps, reward_ex 50.00, reward_in 16.22
# 352 Episode in 19201 steps, reward_ex 80.00, reward_in 52.62
# 353 Episode in 19245 steps, reward_ex 44.00, reward_in 5.74
# 354 Episode in 19343 steps, reward_ex 98.00, reward_in 22.30
# 355 Episode in 19387 steps, reward_ex 44.00, reward_in 5.21
# 356 Episode in 19433 steps, reward_ex 46.00, reward_in 6.91
# 357 Episode in 19526 steps, reward_ex 93.00, reward_in 16.83
# 358 Episode in 19568 steps, reward_ex 42.00, reward_in 4.38
# 359 Episode in 19609 steps, reward_ex 41.00, reward_in 3.80
# 360 Episode in 19659 steps, reward_ex 50.00, reward_in 4.05
# 361 Episode in 19703 steps, reward_ex 44.00, reward_in 3.00
# 362 Episode in 19744 steps, reward_ex 41.00, reward_in 3.58
# 363 Episode in 19782 steps, reward_ex 38.00, reward_in 2.86
# 364 Episode in 19828 steps, reward_ex 46.00, reward_in 4.82
# 365 Episode in 19882 steps, reward_ex 54.00, reward_in 7.96
# 366 Episode in 19968 steps, reward_ex 86.00, reward_in 14.52
# 367 Episode in 20051 steps, reward_ex 83.00, reward_in 9.84
# 368 Episode in 20097 steps, reward_ex 46.00, reward_in 6.90
# 369 Episode in 20163 steps, reward_ex 66.00, reward_in 6.11
# 370 Episode in 20205 steps, reward_ex 42.00, reward_in 4.06
# 371 Episode in 20253 steps, reward_ex 48.00, reward_in 3.47
# 372 Episode in 20298 steps, reward_ex 45.00, reward_in 8.66
# 373 Episode in 20354 steps, reward_ex 56.00, reward_in 3.51
# 374 Episode in 20408 steps, reward_ex 54.00, reward_in 4.57
# 375 Episode in 20457 steps, reward_ex 49.00, reward_in 4.98
# 376 Episode in 20527 steps, reward_ex 70.00, reward_in 11.86
# 377 Episode in 20579 steps, reward_ex 52.00, reward_in 7.29
# 378 Episode in 20619 steps, reward_ex 40.00, reward_in 7.69
# 379 Episode in 20675 steps, reward_ex 56.00, reward_in 7.35
# 380 Episode in 20721 steps, reward_ex 46.00, reward_in 7.34
# 381 Episode in 20778 steps, reward_ex 57.00, reward_in 12.63
# 382 Episode in 20838 steps, reward_ex 60.00, reward_in 11.11
# 383 Episode in 20908 steps, reward_ex 70.00, reward_in 9.31
# 384 Episode in 20948 steps, reward_ex 40.00, reward_in 3.38
# 385 Episode in 20986 steps, reward_ex 38.00, reward_in 3.32
# 386 Episode in 21026 steps, reward_ex 40.00, reward_in 2.87
# 387 Episode in 21062 steps, reward_ex 36.00, reward_in 2.22
# 388 Episode in 21100 steps, reward_ex 38.00, reward_in 2.48
# 389 Episode in 21204 steps, reward_ex 104.00, reward_in 83.46
# 390 Episode in 21278 steps, reward_ex 74.00, reward_in 19.47
# 391 Episode in 21332 steps, reward_ex 54.00, reward_in 25.04
# 392 Episode in 21451 steps, reward_ex 119.00, reward_in 40.36
# 393 Episode in 21510 steps, reward_ex 59.00, reward_in 5.82
# 394 Episode in 21555 steps, reward_ex 45.00, reward_in 4.96
# 395 Episode in 21635 steps, reward_ex 80.00, reward_in 9.04
# 396 Episode in 21703 steps, reward_ex 68.00, reward_in 5.13
# 397 Episode in 21760 steps, reward_ex 57.00, reward_in 5.70
# 398 Episode in 21877 steps, reward_ex 117.00, reward_in 12.50
# 399 Episode in 21994 steps, reward_ex 117.00, reward_in 72.25
# 400 Episode in 22037 steps, reward_ex 43.00, reward_in 13.12
# 401 Episode in 22081 steps, reward_ex 44.00, reward_in 10.32
# 402 Episode in 22130 steps, reward_ex 49.00, reward_in 18.82
# 403 Episode in 22174 steps, reward_ex 44.00, reward_in 6.63
# 404 Episode in 22220 steps, reward_ex 46.00, reward_in 6.07
# 405 Episode in 22274 steps, reward_ex 54.00, reward_in 10.71
# 406 Episode in 22356 steps, reward_ex 82.00, reward_in 8.29
# 407 Episode in 22405 steps, reward_ex 49.00, reward_in 5.94
# 408 Episode in 22527 steps, reward_ex 122.00, reward_in 48.27
# 409 Episode in 22591 steps, reward_ex 64.00, reward_in 8.12
# 410 Episode in 22640 steps, reward_ex 49.00, reward_in 6.75
# 411 Episode in 22690 steps, reward_ex 50.00, reward_in 6.46
# 412 Episode in 22790 steps, reward_ex 100.00, reward_in 13.93
# 413 Episode in 22944 steps, reward_ex 154.00, reward_in 46.01
# 414 Episode in 22990 steps, reward_ex 46.00, reward_in 18.89
# 415 Episode in 23037 steps, reward_ex 47.00, reward_in 18.35
# 416 Episode in 23080 steps, reward_ex 43.00, reward_in 10.04
# 417 Episode in 23131 steps, reward_ex 51.00, reward_in 13.54
# 418 Episode in 23189 steps, reward_ex 58.00, reward_in 14.09
# 419 Episode in 23253 steps, reward_ex 64.00, reward_in 3.99
# 420 Episode in 23311 steps, reward_ex 58.00, reward_in 9.56
# 421 Episode in 23414 steps, reward_ex 103.00, reward_in 57.09
# 422 Episode in 23480 steps, reward_ex 66.00, reward_in 9.04
# 423 Episode in 23595 steps, reward_ex 115.00, reward_in 24.05
# 424 Episode in 23701 steps, reward_ex 106.00, reward_in 11.68
# 425 Episode in 23793 steps, reward_ex 92.00, reward_in 14.97
# 426 Episode in 23886 steps, reward_ex 93.00, reward_in 16.71
# 427 Episode in 23932 steps, reward_ex 46.00, reward_in 5.13
# 428 Episode in 23984 steps, reward_ex 52.00, reward_in 4.69
# 429 Episode in 24098 steps, reward_ex 114.00, reward_in 19.40
# 430 Episode in 24160 steps, reward_ex 62.00, reward_in 9.28
# 431 Episode in 24229 steps, reward_ex 69.00, reward_in 6.08
# 432 Episode in 24277 steps, reward_ex 48.00, reward_in 4.43
# 433 Episode in 24343 steps, reward_ex 66.00, reward_in 5.20
# 434 Episode in 24404 steps, reward_ex 61.00, reward_in 3.60
# 435 Episode in 24469 steps, reward_ex 65.00, reward_in 4.53
# 436 Episode in 24515 steps, reward_ex 46.00, reward_in 5.11
# 437 Episode in 24583 steps, reward_ex 68.00, reward_in 4.62
# 438 Episode in 24637 steps, reward_ex 54.00, reward_in 3.45
# 439 Episode in 24688 steps, reward_ex 51.00, reward_in 2.63
# 440 Episode in 24813 steps, reward_ex 125.00, reward_in 11.91
# 441 Episode in 24856 steps, reward_ex 43.00, reward_in 7.26
# 442 Episode in 24905 steps, reward_ex 49.00, reward_in 8.03
# 443 Episode in 24987 steps, reward_ex 82.00, reward_in 9.34
# 444 Episode in 25053 steps, reward_ex 66.00, reward_in 10.96
# 445 Episode in 25110 steps, reward_ex 57.00, reward_in 6.03
# 446 Episode in 25176 steps, reward_ex 66.00, reward_in 5.69
# 447 Episode in 25308 steps, reward_ex 132.00, reward_in 86.30
# 448 Episode in 25357 steps, reward_ex 49.00, reward_in 7.41
# 449 Episode in 25434 steps, reward_ex 77.00, reward_in 18.13
# 450 Episode in 25497 steps, reward_ex 63.00, reward_in 19.18
# 451 Episode in 25553 steps, reward_ex 56.00, reward_in 5.71
# 452 Episode in 25604 steps, reward_ex 51.00, reward_in 4.67
# 453 Episode in 25725 steps, reward_ex 121.00, reward_in 62.48
# 454 Episode in 25788 steps, reward_ex 63.00, reward_in 8.28
# 455 Episode in 25832 steps, reward_ex 44.00, reward_in 9.67
# 456 Episode in 25980 steps, reward_ex 148.00, reward_in 41.75
# 457 Episode in 26151 steps, reward_ex 171.00, reward_in 70.04
# 458 Episode in 26225 steps, reward_ex 74.00, reward_in 60.29
# 459 Episode in 26271 steps, reward_ex 46.00, reward_in 30.06
# 460 Episode in 26392 steps, reward_ex 121.00, reward_in 109.15
# 461 Episode in 26468 steps, reward_ex 76.00, reward_in 12.22
# 462 Episode in 26519 steps, reward_ex 51.00, reward_in 8.10
# 463 Episode in 26580 steps, reward_ex 61.00, reward_in 7.17
# 464 Episode in 26641 steps, reward_ex 61.00, reward_in 7.09
# 465 Episode in 26693 steps, reward_ex 52.00, reward_in 5.59
# 466 Episode in 26756 steps, reward_ex 63.00, reward_in 12.91
# 467 Episode in 26820 steps, reward_ex 64.00, reward_in 4.32
# 468 Episode in 26894 steps, reward_ex 74.00, reward_in 5.65
# 469 Episode in 26951 steps, reward_ex 57.00, reward_in 3.72
# 470 Episode in 27006 steps, reward_ex 55.00, reward_in 6.23
# 471 Episode in 27076 steps, reward_ex 70.00, reward_in 4.11
# 472 Episode in 27133 steps, reward_ex 57.00, reward_in 3.92
# 473 Episode in 27198 steps, reward_ex 65.00, reward_in 3.18
# 474 Episode in 27243 steps, reward_ex 45.00, reward_in 2.68
# 475 Episode in 27288 steps, reward_ex 45.00, reward_in 3.43
# 476 Episode in 27429 steps, reward_ex 141.00, reward_in 87.81
# 477 Episode in 27476 steps, reward_ex 47.00, reward_in 5.65
# 478 Episode in 27517 steps, reward_ex 41.00, reward_in 4.81
# 479 Episode in 27572 steps, reward_ex 55.00, reward_in 5.61
# 480 Episode in 27634 steps, reward_ex 62.00, reward_in 7.24
# 481 Episode in 27752 steps, reward_ex 118.00, reward_in 48.63
# 482 Episode in 27805 steps, reward_ex 53.00, reward_in 6.81
# 483 Episode in 27922 steps, reward_ex 117.00, reward_in 17.97
# 484 Episode in 27990 steps, reward_ex 68.00, reward_in 6.38
# 485 Episode in 28035 steps, reward_ex 45.00, reward_in 5.79
# 486 Episode in 28094 steps, reward_ex 59.00, reward_in 5.01
# 487 Episode in 28143 steps, reward_ex 49.00, reward_in 4.53
# 488 Episode in 28199 steps, reward_ex 56.00, reward_in 5.25
# 489 Episode in 28264 steps, reward_ex 65.00, reward_in 6.88
# 490 Episode in 28326 steps, reward_ex 62.00, reward_in 3.94
# 491 Episode in 28388 steps, reward_ex 62.00, reward_in 4.00
# 492 Episode in 28460 steps, reward_ex 72.00, reward_in 5.11
# 493 Episode in 28524 steps, reward_ex 64.00, reward_in 2.75
# 494 Episode in 28587 steps, reward_ex 63.00, reward_in 2.91
# 495 Episode in 28701 steps, reward_ex 114.00, reward_in 16.60
# 496 Episode in 28762 steps, reward_ex 61.00, reward_in 4.32
# 497 Episode in 28811 steps, reward_ex 49.00, reward_in 3.73
# 498 Episode in 28884 steps, reward_ex 73.00, reward_in 6.47
# 499 Episode in 28939 steps, reward_ex 55.00, reward_in 4.21
# 500 Episode in 28992 steps, reward_ex 53.00, reward_in 3.40
# 501 Episode in 29063 steps, reward_ex 71.00, reward_in 3.45
# 502 Episode in 29123 steps, reward_ex 60.00, reward_in 4.02
# 503 Episode in 29253 steps, reward_ex 130.00, reward_in 28.34
# 504 Episode in 29315 steps, reward_ex 62.00, reward_in 6.14
# 505 Episode in 29387 steps, reward_ex 72.00, reward_in 5.40
# 506 Episode in 29564 steps, reward_ex 177.00, reward_in 72.16
# 507 Episode in 29631 steps, reward_ex 67.00, reward_in 61.70
# 508 Episode in 29730 steps, reward_ex 99.00, reward_in 73.99
# 509 Episode in 29777 steps, reward_ex 47.00, reward_in 40.92
# 510 Episode in 29840 steps, reward_ex 63.00, reward_in 42.74
# 511 Episode in 29984 steps, reward_ex 144.00, reward_in 33.65
# 512 Episode in 30036 steps, reward_ex 52.00, reward_in 5.97
# 513 Episode in 30173 steps, reward_ex 137.00, reward_in 15.64
# 514 Episode in 30227 steps, reward_ex 54.00, reward_in 6.53
# 515 Episode in 30296 steps, reward_ex 69.00, reward_in 4.51
# 516 Episode in 30349 steps, reward_ex 53.00, reward_in 3.69
# 517 Episode in 30398 steps, reward_ex 49.00, reward_in 2.58
# 518 Episode in 30456 steps, reward_ex 58.00, reward_in 3.74
# 519 Episode in 30508 steps, reward_ex 52.00, reward_in 2.18
# 520 Episode in 30565 steps, reward_ex 57.00, reward_in 2.49
# 521 Episode in 30623 steps, reward_ex 58.00, reward_in 2.76
# 522 Episode in 30684 steps, reward_ex 61.00, reward_in 2.40
# 523 Episode in 30750 steps, reward_ex 66.00, reward_in 3.27
# 524 Episode in 30825 steps, reward_ex 75.00, reward_in 4.45
# 525 Episode in 30959 steps, reward_ex 134.00, reward_in 13.68
# 526 Episode in 31039 steps, reward_ex 80.00, reward_in 9.38
# 527 Episode in 31173 steps, reward_ex 134.00, reward_in 33.61
# 528 Episode in 31228 steps, reward_ex 55.00, reward_in 35.92
# 529 Episode in 31290 steps, reward_ex 62.00, reward_in 6.22
# 530 Episode in 31348 steps, reward_ex 58.00, reward_in 5.56
# 531 Episode in 31398 steps, reward_ex 50.00, reward_in 3.75
# 532 Episode in 31493 steps, reward_ex 95.00, reward_in 7.36
# 533 Episode in 31590 steps, reward_ex 97.00, reward_in 13.84
# 534 Episode in 31650 steps, reward_ex 60.00, reward_in 3.23
# 535 Episode in 31714 steps, reward_ex 64.00, reward_in 6.22
# 536 Episode in 31831 steps, reward_ex 117.00, reward_in 12.95
# 537 Episode in 31888 steps, reward_ex 57.00, reward_in 5.79
# 538 Episode in 31946 steps, reward_ex 58.00, reward_in 6.39
# 539 Episode in 32012 steps, reward_ex 66.00, reward_in 6.03
# 540 Episode in 32067 steps, reward_ex 55.00, reward_in 4.32
# 541 Episode in 32185 steps, reward_ex 118.00, reward_in 22.26
# 542 Episode in 32255 steps, reward_ex 70.00, reward_in 4.87
# 543 Episode in 32330 steps, reward_ex 75.00, reward_in 13.43
# 544 Episode in 32391 steps, reward_ex 61.00, reward_in 9.30
# 545 Episode in 32487 steps, reward_ex 96.00, reward_in 14.74
# 546 Episode in 32549 steps, reward_ex 62.00, reward_in 5.65
# 547 Episode in 32661 steps, reward_ex 112.00, reward_in 8.93
# 548 Episode in 32741 steps, reward_ex 80.00, reward_in 5.24
# 549 Episode in 32806 steps, reward_ex 65.00, reward_in 4.49
# 550 Episode in 32933 steps, reward_ex 127.00, reward_in 10.92
# 551 Episode in 32996 steps, reward_ex 63.00, reward_in 4.19
# 552 Episode in 33074 steps, reward_ex 78.00, reward_in 5.06
# 553 Episode in 33147 steps, reward_ex 73.00, reward_in 5.20
# 554 Episode in 33267 steps, reward_ex 120.00, reward_in 30.31
# 555 Episode in 33342 steps, reward_ex 75.00, reward_in 13.44
# 556 Episode in 33437 steps, reward_ex 95.00, reward_in 16.53
# 557 Episode in 33529 steps, reward_ex 92.00, reward_in 14.18
# 558 Episode in 33599 steps, reward_ex 70.00, reward_in 4.35
# 559 Episode in 33686 steps, reward_ex 87.00, reward_in 4.41
# 560 Episode in 33777 steps, reward_ex 91.00, reward_in 4.30
# 561 Episode in 33848 steps, reward_ex 71.00, reward_in 3.69
# 562 Episode in 33936 steps, reward_ex 88.00, reward_in 3.67
# 563 Episode in 34025 steps, reward_ex 89.00, reward_in 4.36
# 564 Episode in 34102 steps, reward_ex 77.00, reward_in 3.96
# 565 Episode in 34201 steps, reward_ex 99.00, reward_in 6.94
# 566 Episode in 34294 steps, reward_ex 93.00, reward_in 3.98
# 567 Episode in 34372 steps, reward_ex 78.00, reward_in 4.65
# 568 Episode in 34461 steps, reward_ex 89.00, reward_in 5.86
# 569 Episode in 34562 steps, reward_ex 101.00, reward_in 7.86
# 570 Episode in 34693 steps, reward_ex 131.00, reward_in 12.11
# 571 Episode in 34783 steps, reward_ex 90.00, reward_in 10.63
# 572 Episode in 34879 steps, reward_ex 96.00, reward_in 9.42
# 573 Episode in 35040 steps, reward_ex 161.00, reward_in 17.00
# 574 Episode in 35108 steps, reward_ex 68.00, reward_in 5.30
# 575 Episode in 35215 steps, reward_ex 107.00, reward_in 8.88
# 576 Episode in 35287 steps, reward_ex 72.00, reward_in 2.83
# 577 Episode in 35423 steps, reward_ex 136.00, reward_in 5.81
# 578 Episode in 35496 steps, reward_ex 73.00, reward_in 4.34
# 579 Episode in 35583 steps, reward_ex 87.00, reward_in 6.83
# 580 Episode in 35665 steps, reward_ex 82.00, reward_in 7.24
# 581 Episode in 35735 steps, reward_ex 70.00, reward_in 4.90
# 582 Episode in 35833 steps, reward_ex 98.00, reward_in 4.76
# 583 Episode in 35915 steps, reward_ex 82.00, reward_in 2.72
# 584 Episode in 36104 steps, reward_ex 189.00, reward_in 20.21
# 585 Episode in 36176 steps, reward_ex 72.00, reward_in 25.08
# 586 Episode in 36288 steps, reward_ex 112.00, reward_in 32.46
# 587 Episode in 36378 steps, reward_ex 90.00, reward_in 13.47
# 588 Episode in 36448 steps, reward_ex 70.00, reward_in 4.80
# 589 Episode in 36538 steps, reward_ex 90.00, reward_in 4.43
# 590 Episode in 36631 steps, reward_ex 93.00, reward_in 4.36
# 591 Episode in 36850 steps, reward_ex 219.00, reward_in 110.09
# 592 Episode in 36939 steps, reward_ex 89.00, reward_in 43.97
# 593 Episode in 37054 steps, reward_ex 115.00, reward_in 26.30
# 594 Episode in 37135 steps, reward_ex 81.00, reward_in 27.47
# 595 Episode in 37225 steps, reward_ex 90.00, reward_in 5.27
# 596 Episode in 37307 steps, reward_ex 82.00, reward_in 4.76
# 597 Episode in 37395 steps, reward_ex 88.00, reward_in 3.38
# 598 Episode in 37486 steps, reward_ex 91.00, reward_in 3.89
# 599 Episode in 37583 steps, reward_ex 97.00, reward_in 5.03
# 600 Episode in 37649 steps, reward_ex 66.00, reward_in 2.78
# 601 Episode in 37718 steps, reward_ex 69.00, reward_in 2.44
# 602 Episode in 37795 steps, reward_ex 77.00, reward_in 2.33
# 603 Episode in 37891 steps, reward_ex 96.00, reward_in 3.58
# 604 Episode in 37978 steps, reward_ex 87.00, reward_in 2.34
# 605 Episode in 38039 steps, reward_ex 61.00, reward_in 2.53
# 606 Episode in 38117 steps, reward_ex 78.00, reward_in 2.51
# 607 Episode in 38212 steps, reward_ex 95.00, reward_in 3.35
# 608 Episode in 38276 steps, reward_ex 64.00, reward_in 1.72
# 609 Episode in 38336 steps, reward_ex 60.00, reward_in 2.24
# 610 Episode in 38412 steps, reward_ex 76.00, reward_in 2.60
# 611 Episode in 38484 steps, reward_ex 72.00, reward_in 2.50
# 612 Episode in 38659 steps, reward_ex 175.00, reward_in 33.77
# 613 Episode in 38719 steps, reward_ex 60.00, reward_in 32.66
# 614 Episode in 38909 steps, reward_ex 190.00, reward_in 95.38
# 615 Episode in 39037 steps, reward_ex 128.00, reward_in 19.42
# 616 Episode in 39118 steps, reward_ex 81.00, reward_in 3.91
# 617 Episode in 39189 steps, reward_ex 71.00, reward_in 2.80
# 618 Episode in 39273 steps, reward_ex 84.00, reward_in 4.20
# 619 Episode in 39377 steps, reward_ex 104.00, reward_in 7.89
# 620 Episode in 39445 steps, reward_ex 68.00, reward_in 3.61
# 621 Episode in 39602 steps, reward_ex 157.00, reward_in 26.74
# 622 Episode in 39698 steps, reward_ex 96.00, reward_in 8.04
# 623 Episode in 39762 steps, reward_ex 64.00, reward_in 9.26
# 624 Episode in 39851 steps, reward_ex 89.00, reward_in 9.68
# 625 Episode in 39939 steps, reward_ex 88.00, reward_in 12.87
# 626 Episode in 40019 steps, reward_ex 80.00, reward_in 10.18
# 627 Episode in 40104 steps, reward_ex 85.00, reward_in 4.94
# 628 Episode in 40176 steps, reward_ex 72.00, reward_in 2.96
# 629 Episode in 40257 steps, reward_ex 81.00, reward_in 2.41
# 630 Episode in 40340 steps, reward_ex 83.00, reward_in 3.84
# 631 Episode in 40423 steps, reward_ex 83.00, reward_in 4.69
# 632 Episode in 40508 steps, reward_ex 85.00, reward_in 3.18
# 633 Episode in 40721 steps, reward_ex 213.00, reward_in 47.26
# 634 Episode in 40824 steps, reward_ex 103.00, reward_in 81.33
# 635 Episode in 40937 steps, reward_ex 113.00, reward_in 55.43
# 636 Episode in 41016 steps, reward_ex 79.00, reward_in 11.09
# 637 Episode in 41104 steps, reward_ex 88.00, reward_in 3.76
# 638 Episode in 41415 steps, reward_ex 311.00, reward_in 134.40
# 639 Episode in 41494 steps, reward_ex 79.00, reward_in 75.50
# 640 Episode in 41569 steps, reward_ex 75.00, reward_in 74.95
# 641 Episode in 41637 steps, reward_ex 68.00, reward_in 42.36
# 642 Episode in 41701 steps, reward_ex 64.00, reward_in 35.29
# 643 Episode in 41796 steps, reward_ex 95.00, reward_in 34.63
# 644 Episode in 41876 steps, reward_ex 80.00, reward_in 16.48
# 645 Episode in 41962 steps, reward_ex 86.00, reward_in 11.13
# 646 Episode in 42054 steps, reward_ex 92.00, reward_in 9.93
# 647 Episode in 42120 steps, reward_ex 66.00, reward_in 6.82
# 648 Episode in 42188 steps, reward_ex 68.00, reward_in 8.75
# 649 Episode in 42269 steps, reward_ex 81.00, reward_in 7.77
# 650 Episode in 42353 steps, reward_ex 84.00, reward_in 5.51
# 651 Episode in 42434 steps, reward_ex 81.00, reward_in 3.70
# 652 Episode in 42636 steps, reward_ex 202.00, reward_in 93.12
# 653 Episode in 42800 steps, reward_ex 164.00, reward_in 126.34
# 654 Episode in 42871 steps, reward_ex 71.00, reward_in 13.29
# 655 Episode in 42950 steps, reward_ex 79.00, reward_in 21.24
# 656 Episode in 43008 steps, reward_ex 58.00, reward_in 15.93
# 657 Episode in 43075 steps, reward_ex 67.00, reward_in 4.29
# 658 Episode in 43140 steps, reward_ex 65.00, reward_in 3.82
# 659 Episode in 43211 steps, reward_ex 71.00, reward_in 2.67
# 660 Episode in 43320 steps, reward_ex 109.00, reward_in 6.59
# 661 Episode in 43445 steps, reward_ex 125.00, reward_in 5.76
# 662 Episode in 43538 steps, reward_ex 93.00, reward_in 3.15
# 663 Episode in 43609 steps, reward_ex 71.00, reward_in 5.50
# 664 Episode in 43745 steps, reward_ex 136.00, reward_in 11.34
# 665 Episode in 43820 steps, reward_ex 75.00, reward_in 3.91
# 666 Episode in 43883 steps, reward_ex 63.00, reward_in 4.97
# 667 Episode in 43954 steps, reward_ex 71.00, reward_in 3.65
# 668 Episode in 44038 steps, reward_ex 84.00, reward_in 5.21
# 669 Episode in 44095 steps, reward_ex 57.00, reward_in 2.35
# 670 Episode in 44179 steps, reward_ex 84.00, reward_in 2.24
# 671 Episode in 44251 steps, reward_ex 72.00, reward_in 2.15
# 672 Episode in 44324 steps, reward_ex 73.00, reward_in 1.92
# 673 Episode in 44439 steps, reward_ex 115.00, reward_in 8.01
# 674 Episode in 44576 steps, reward_ex 137.00, reward_in 8.36
# 675 Episode in 44652 steps, reward_ex 76.00, reward_in 8.79
# 676 Episode in 44728 steps, reward_ex 76.00, reward_in 3.97
# 677 Episode in 44819 steps, reward_ex 91.00, reward_in 5.76
# 678 Episode in 44900 steps, reward_ex 81.00, reward_in 3.25
# 679 Episode in 44981 steps, reward_ex 81.00, reward_in 2.29
# 680 Episode in 45056 steps, reward_ex 75.00, reward_in 2.44
# 681 Episode in 45118 steps, reward_ex 62.00, reward_in 1.77
# 682 Episode in 45224 steps, reward_ex 106.00, reward_in 12.53
# 683 Episode in 45303 steps, reward_ex 79.00, reward_in 5.13
# 684 Episode in 45383 steps, reward_ex 80.00, reward_in 5.01
# 685 Episode in 45464 steps, reward_ex 81.00, reward_in 4.41
# 686 Episode in 45524 steps, reward_ex 60.00, reward_in 2.79
# 687 Episode in 45580 steps, reward_ex 56.00, reward_in 3.01
# 688 Episode in 45654 steps, reward_ex 74.00, reward_in 4.05
# 689 Episode in 45716 steps, reward_ex 62.00, reward_in 2.90
# 690 Episode in 45790 steps, reward_ex 74.00, reward_in 2.92
# 691 Episode in 45850 steps, reward_ex 60.00, reward_in 2.38
# 692 Episode in 45903 steps, reward_ex 53.00, reward_in 1.28
# 693 Episode in 45953 steps, reward_ex 50.00, reward_in 1.33
# 694 Episode in 46004 steps, reward_ex 51.00, reward_in 1.60
# 695 Episode in 46053 steps, reward_ex 49.00, reward_in 1.64
# 696 Episode in 46135 steps, reward_ex 82.00, reward_in 5.81
# 697 Episode in 46196 steps, reward_ex 61.00, reward_in 3.07
# 698 Episode in 46251 steps, reward_ex 55.00, reward_in 2.69
# 699 Episode in 46330 steps, reward_ex 79.00, reward_in 3.87
# 700 Episode in 46381 steps, reward_ex 51.00, reward_in 2.56
# 701 Episode in 46477 steps, reward_ex 96.00, reward_in 6.70
# 702 Episode in 46537 steps, reward_ex 60.00, reward_in 3.21
# 703 Episode in 46602 steps, reward_ex 65.00, reward_in 2.99
# 704 Episode in 46655 steps, reward_ex 53.00, reward_in 2.37
# 705 Episode in 46704 steps, reward_ex 49.00, reward_in 1.89
# 706 Episode in 46761 steps, reward_ex 57.00, reward_in 2.33
# 707 Episode in 46818 steps, reward_ex 57.00, reward_in 2.66
# 708 Episode in 46884 steps, reward_ex 66.00, reward_in 2.88
# 709 Episode in 47057 steps, reward_ex 173.00, reward_in 44.31
# 710 Episode in 47121 steps, reward_ex 64.00, reward_in 6.34
# 711 Episode in 47246 steps, reward_ex 125.00, reward_in 28.68
# 712 Episode in 47306 steps, reward_ex 60.00, reward_in 32.38
# 713 Episode in 47455 steps, reward_ex 149.00, reward_in 19.48
# 714 Episode in 47512 steps, reward_ex 57.00, reward_in 4.29
# 715 Episode in 47584 steps, reward_ex 72.00, reward_in 5.29
# 716 Episode in 47642 steps, reward_ex 58.00, reward_in 3.44
# 717 Episode in 47694 steps, reward_ex 52.00, reward_in 3.71
# 718 Episode in 47814 steps, reward_ex 120.00, reward_in 13.21
# 719 Episode in 47873 steps, reward_ex 59.00, reward_in 2.85
# 720 Episode in 47950 steps, reward_ex 77.00, reward_in 4.63
# 721 Episode in 48022 steps, reward_ex 72.00, reward_in 4.89
# 722 Episode in 48096 steps, reward_ex 74.00, reward_in 4.13
# 723 Episode in 48221 steps, reward_ex 125.00, reward_in 16.30
# 724 Episode in 48295 steps, reward_ex 74.00, reward_in 7.46
# 725 Episode in 48417 steps, reward_ex 122.00, reward_in 16.64
# 726 Episode in 48477 steps, reward_ex 60.00, reward_in 3.78
# 727 Episode in 48540 steps, reward_ex 63.00, reward_in 3.35
# 728 Episode in 48658 steps, reward_ex 118.00, reward_in 11.68
# 729 Episode in 48722 steps, reward_ex 64.00, reward_in 3.17
# 730 Episode in 49166 steps, reward_ex 444.00, reward_in 219.76
# 731 Episode in 49226 steps, reward_ex 60.00, reward_in 60.00
# 732 Episode in 49286 steps, reward_ex 60.00, reward_in 60.00
# 733 Episode in 49483 steps, reward_ex 197.00, reward_in 138.17
# 734 Episode in 49561 steps, reward_ex 78.00, reward_in 23.73
# 735 Episode in 49615 steps, reward_ex 54.00, reward_in 17.21
# 736 Episode in 49672 steps, reward_ex 57.00, reward_in 7.96
# 737 Episode in 49746 steps, reward_ex 74.00, reward_in 13.52
# 738 Episode in 49809 steps, reward_ex 63.00, reward_in 9.44
# 739 Episode in 49882 steps, reward_ex 73.00, reward_in 3.50
# 740 Episode in 49952 steps, reward_ex 70.00, reward_in 2.54
# 741 Episode in 50076 steps, reward_ex 124.00, reward_in 16.69
# 742 Episode in 50130 steps, reward_ex 54.00, reward_in 2.83
# 743 Episode in 50185 steps, reward_ex 55.00, reward_in 3.62
# 744 Episode in 50245 steps, reward_ex 60.00, reward_in 3.79
# 745 Episode in 50331 steps, reward_ex 86.00, reward_in 12.53
# 746 Episode in 50420 steps, reward_ex 89.00, reward_in 4.08
# 747 Episode in 50475 steps, reward_ex 55.00, reward_in 2.89
# 748 Episode in 50529 steps, reward_ex 54.00, reward_in 2.34
# 749 Episode in 50607 steps, reward_ex 78.00, reward_in 2.57
# 750 Episode in 50698 steps, reward_ex 91.00, reward_in 4.82
# 751 Episode in 50780 steps, reward_ex 82.00, reward_in 2.60
# 752 Episode in 50911 steps, reward_ex 131.00, reward_in 5.87
# 753 Episode in 51035 steps, reward_ex 124.00, reward_in 5.92
# 754 Episode in 51153 steps, reward_ex 118.00, reward_in 8.31
# 755 Episode in 51367 steps, reward_ex 214.00, reward_in 51.41
# 756 Episode in 51435 steps, reward_ex 68.00, reward_in 49.09
# 757 Episode in 51489 steps, reward_ex 54.00, reward_in 16.87
# 758 Episode in 51595 steps, reward_ex 106.00, reward_in 48.99
# 759 Episode in 51654 steps, reward_ex 59.00, reward_in 5.11
# 760 Episode in 51717 steps, reward_ex 63.00, reward_in 3.46
# 761 Episode in 51779 steps, reward_ex 62.00, reward_in 3.53
# 762 Episode in 51921 steps, reward_ex 142.00, reward_in 23.15
# 763 Episode in 51970 steps, reward_ex 49.00, reward_in 2.57
# 764 Episode in 52024 steps, reward_ex 54.00, reward_in 4.95
# 765 Episode in 52100 steps, reward_ex 76.00, reward_in 5.76
# 766 Episode in 52152 steps, reward_ex 52.00, reward_in 1.78
# 767 Episode in 52204 steps, reward_ex 52.00, reward_in 1.95
# 768 Episode in 52275 steps, reward_ex 71.00, reward_in 2.03
# 769 Episode in 52325 steps, reward_ex 50.00, reward_in 2.67
# 770 Episode in 52382 steps, reward_ex 57.00, reward_in 2.14
# 771 Episode in 52483 steps, reward_ex 101.00, reward_in 8.94
# 772 Episode in 52532 steps, reward_ex 49.00, reward_in 1.67
# 773 Episode in 52592 steps, reward_ex 60.00, reward_in 2.50
# 774 Episode in 52647 steps, reward_ex 55.00, reward_in 2.12
# 775 Episode in 52689 steps, reward_ex 42.00, reward_in 2.09
# 776 Episode in 52751 steps, reward_ex 62.00, reward_in 2.14
# 777 Episode in 52839 steps, reward_ex 88.00, reward_in 7.24
# 778 Episode in 52892 steps, reward_ex 53.00, reward_in 2.24
# 779 Episode in 52953 steps, reward_ex 61.00, reward_in 5.38
# 780 Episode in 53055 steps, reward_ex 102.00, reward_in 7.43
# 781 Episode in 53110 steps, reward_ex 55.00, reward_in 2.29
# 782 Episode in 53171 steps, reward_ex 61.00, reward_in 2.50
# 783 Episode in 53224 steps, reward_ex 53.00, reward_in 3.26
# 784 Episode in 53455 steps, reward_ex 231.00, reward_in 130.88
# 785 Episode in 53512 steps, reward_ex 57.00, reward_in 54.72
# 786 Episode in 53591 steps, reward_ex 79.00, reward_in 77.78
# 787 Episode in 53644 steps, reward_ex 53.00, reward_in 42.91
# 788 Episode in 53704 steps, reward_ex 60.00, reward_in 14.68
# 789 Episode in 53859 steps, reward_ex 155.00, reward_in 40.50
# 790 Episode in 53916 steps, reward_ex 57.00, reward_in 14.75
# 791 Episode in 53971 steps, reward_ex 55.00, reward_in 8.79
# 792 Episode in 54020 steps, reward_ex 49.00, reward_in 11.47
# ...
# 1525 Episode in 103082 steps, reward_ex 58.00, reward_in 5.62
# 1526 Episode in 103142 steps, reward_ex 60.00, reward_in 3.45
# 1527 Episode in 103194 steps, reward_ex 52.00, reward_in 4.07
# 1528 Episode in 103252 steps, reward_ex 58.00, reward_in 4.97
# 1529 Episode in 103286 steps, reward_ex 34.00, reward_in 1.67
# 1530 Episode in 103336 steps, reward_ex 50.00, reward_in 2.44
# 1531 Episode in 103380 steps, reward_ex 44.00, reward_in 1.25
# 1532 Episode in 103436 steps, reward_ex 56.00, reward_in 2.64
# 1533 Episode in 103476 steps, reward_ex 40.00, reward_in 1.34
# 1534 Episode in 103517 steps, reward_ex 41.00, reward_in 2.71
# 1535 Episode in 103574 steps, reward_ex 57.00, reward_in 2.31
# 1536 Episode in 103630 steps, reward_ex 56.00, reward_in 3.29
# 1537 Episode in 103688 steps, reward_ex 58.00, reward_in 2.13
# 1538 Episode in 103725 steps, reward_ex 37.00, reward_in 1.65
# 1539 Episode in 103759 steps, reward_ex 34.00, reward_in 4.80
# 1540 Episode in 103804 steps, reward_ex 45.00, reward_in 1.83
# 1541 Episode in 103851 steps, reward_ex 47.00, reward_in 2.67
# 1542 Episode in 103905 steps, reward_ex 54.00, reward_in 6.81
# 1543 Episode in 103949 steps, reward_ex 44.00, reward_in 2.06
# 1544 Episode in 103985 steps, reward_ex 36.00, reward_in 1.01
# 1545 Episode in 104031 steps, reward_ex 46.00, reward_in 1.61
# 1546 Episode in 104081 steps, reward_ex 50.00, reward_in 1.62
# 1547 Episode in 104128 steps, reward_ex 47.00, reward_in 0.98
# 1548 Episode in 104168 steps, reward_ex 40.00, reward_in 0.96
# 1549 Episode in 104205 steps, reward_ex 37.00, reward_in 1.11
# 1550 Episode in 104248 steps, reward_ex 43.00, reward_in 1.44
# 1551 Episode in 104284 steps, reward_ex 36.00, reward_in 0.89
# 1552 Episode in 104344 steps, reward_ex 60.00, reward_in 9.16
# 1553 Episode in 104383 steps, reward_ex 39.00, reward_in 1.00
# 1554 Episode in 104441 steps, reward_ex 58.00, reward_in 2.14
# 1555 Episode in 104475 steps, reward_ex 34.00, reward_in 1.59
# 1556 Episode in 104527 steps, reward_ex 52.00, reward_in 2.51
# 1557 Episode in 104592 steps, reward_ex 65.00, reward_in 9.15
# 1558 Episode in 104645 steps, reward_ex 53.00, reward_in 2.74
# 1559 Episode in 104689 steps, reward_ex 44.00, reward_in 1.43
# 1560 Episode in 104742 steps, reward_ex 53.00, reward_in 1.63
# 1561 Episode in 104794 steps, reward_ex 52.00, reward_in 0.98
# 1562 Episode in 104850 steps, reward_ex 56.00, reward_in 1.21
# 1563 Episode in 104907 steps, reward_ex 57.00, reward_in 1.18
# 1564 Episode in 104965 steps, reward_ex 58.00, reward_in 4.28
# 1565 Episode in 105033 steps, reward_ex 68.00, reward_in 2.34
# 1566 Episode in 105076 steps, reward_ex 43.00, reward_in 2.41
# 1567 Episode in 105112 steps, reward_ex 36.00, reward_in 1.07
# 1568 Episode in 105167 steps, reward_ex 55.00, reward_in 2.57
# 1569 Episode in 105237 steps, reward_ex 70.00, reward_in 2.48
# 1570 Episode in 105271 steps, reward_ex 34.00, reward_in 2.62
# 1571 Episode in 105333 steps, reward_ex 62.00, reward_in 4.10
# 1572 Episode in 105371 steps, reward_ex 38.00, reward_in 1.83
# 1573 Episode in 105423 steps, reward_ex 52.00, reward_in 2.01
# 1574 Episode in 105463 steps, reward_ex 40.00, reward_in 1.60
# 1575 Episode in 105515 steps, reward_ex 52.00, reward_in 1.54
# 1576 Episode in 105561 steps, reward_ex 46.00, reward_in 1.92
# 1577 Episode in 105608 steps, reward_ex 47.00, reward_in 1.38
# 1578 Episode in 105670 steps, reward_ex 62.00, reward_in 3.55
# 1579 Episode in 105712 steps, reward_ex 42.00, reward_in 12.94
# 1580 Episode in 105755 steps, reward_ex 43.00, reward_in 4.04
# 1581 Episode in 105800 steps, reward_ex 45.00, reward_in 2.78
# 1582 Episode in 105871 steps, reward_ex 71.00, reward_in 3.48
# 1583 Episode in 105908 steps, reward_ex 37.00, reward_in 1.87
# 1584 Episode in 105953 steps, reward_ex 45.00, reward_in 1.49
# 1585 Episode in 105992 steps, reward_ex 39.00, reward_in 2.14
# 1586 Episode in 106046 steps, reward_ex 54.00, reward_in 5.60
# 1587 Episode in 106108 steps, reward_ex 62.00, reward_in 4.57
# 1588 Episode in 106170 steps, reward_ex 62.00, reward_in 5.39
# 1589 Episode in 106238 steps, reward_ex 68.00, reward_in 2.92
# 1590 Episode in 106302 steps, reward_ex 64.00, reward_in 3.19
# 1591 Episode in 106359 steps, reward_ex 57.00, reward_in 4.04
# 1592 Episode in 106403 steps, reward_ex 44.00, reward_in 1.91
# 1593 Episode in 106465 steps, reward_ex 62.00, reward_in 3.46
# 1594 Episode in 106509 steps, reward_ex 44.00, reward_in 1.59
# 1595 Episode in 106577 steps, reward_ex 68.00, reward_in 3.70
# 1596 Episode in 106632 steps, reward_ex 55.00, reward_in 2.82
# 1597 Episode in 106686 steps, reward_ex 54.00, reward_in 1.64
# 1598 Episode in 106756 steps, reward_ex 70.00, reward_in 2.11
# 1599 Episode in 106804 steps, reward_ex 48.00, reward_in 2.98
# 1600 Episode in 106868 steps, reward_ex 64.00, reward_in 2.42
# 1601 Episode in 106906 steps, reward_ex 38.00, reward_in 1.94
# 1602 Episode in 106947 steps, reward_ex 41.00, reward_in 1.81
# 1603 Episode in 106983 steps, reward_ex 36.00, reward_in 1.00
# 1604 Episode in 107017 steps, reward_ex 34.00, reward_in 1.20
# 1605 Episode in 107066 steps, reward_ex 49.00, reward_in 2.15
# 1606 Episode in 107102 steps, reward_ex 36.00, reward_in 1.51
# 1607 Episode in 107141 steps, reward_ex 39.00, reward_in 1.17
# 1608 Episode in 107183 steps, reward_ex 42.00, reward_in 1.33
# 1609 Episode in 107227 steps, reward_ex 44.00, reward_in 1.05
# 1610 Episode in 107264 steps, reward_ex 37.00, reward_in 0.82
# 1611 Episode in 107306 steps, reward_ex 42.00, reward_in 0.97
# 1612 Episode in 107366 steps, reward_ex 60.00, reward_in 1.88
# 1613 Episode in 107412 steps, reward_ex 46.00, reward_in 1.09
# 1614 Episode in 107459 steps, reward_ex 47.00, reward_in 1.40
# 1615 Episode in 107503 steps, reward_ex 44.00, reward_in 1.20
# 1616 Episode in 107559 steps, reward_ex 56.00, reward_in 3.72
# 1617 Episode in 107607 steps, reward_ex 48.00, reward_in 1.21
# 1618 Episode in 107667 steps, reward_ex 60.00, reward_in 5.70
# 1619 Episode in 107708 steps, reward_ex 41.00, reward_in 1.44
# 1620 Episode in 107764 steps, reward_ex 56.00, reward_in 1.73
# 1621 Episode in 107840 steps, reward_ex 76.00, reward_in 3.47
# 1622 Episode in 107899 steps, reward_ex 59.00, reward_in 3.14
# 1623 Episode in 107939 steps, reward_ex 40.00, reward_in 1.79
# 1624 Episode in 107973 steps, reward_ex 34.00, reward_in 2.19
# 1625 Episode in 108031 steps, reward_ex 58.00, reward_in 4.76
# 1626 Episode in 108089 steps, reward_ex 58.00, reward_in 2.60
# 1627 Episode in 108151 steps, reward_ex 62.00, reward_in 4.03
# 1628 Episode in 108187 steps, reward_ex 36.00, reward_in 1.43
# 1629 Episode in 108230 steps, reward_ex 43.00, reward_in 1.89
# 1630 Episode in 108270 steps, reward_ex 40.00, reward_in 1.69
# 1631 Episode in 108314 steps, reward_ex 44.00, reward_in 1.84
# 1632 Episode in 108364 steps, reward_ex 50.00, reward_in 2.03
# 1633 Episode in 108436 steps, reward_ex 72.00, reward_in 7.49
# 1634 Episode in 108484 steps, reward_ex 48.00, reward_in 12.35
# 1635 Episode in 108522 steps, reward_ex 38.00, reward_in 5.72
# 1636 Episode in 108578 steps, reward_ex 56.00, reward_in 4.91
# 1637 Episode in 108640 steps, reward_ex 62.00, reward_in 3.90
# 1638 Episode in 108688 steps, reward_ex 48.00, reward_in 2.08
# 1639 Episode in 108733 steps, reward_ex 45.00, reward_in 2.78
# 1640 Episode in 108809 steps, reward_ex 76.00, reward_in 3.39
# 1641 Episode in 108863 steps, reward_ex 54.00, reward_in 1.65
# 1642 Episode in 108909 steps, reward_ex 46.00, reward_in 1.50
# 1643 Episode in 108957 steps, reward_ex 48.00, reward_in 1.37
# 1644 Episode in 109003 steps, reward_ex 46.00, reward_in 1.46
# 1645 Episode in 109043 steps, reward_ex 40.00, reward_in 4.50
# 1646 Episode in 109079 steps, reward_ex 36.00, reward_in 5.27
# 1647 Episode in 109119 steps, reward_ex 40.00, reward_in 4.45
# 1648 Episode in 109170 steps, reward_ex 51.00, reward_in 3.59
# 1649 Episode in 109216 steps, reward_ex 46.00, reward_in 2.44
# 1650 Episode in 109274 steps, reward_ex 58.00, reward_in 2.08
# 1651 Episode in 109312 steps, reward_ex 38.00, reward_in 1.20
# 1652 Episode in 109354 steps, reward_ex 42.00, reward_in 1.28
# 1653 Episode in 109394 steps, reward_ex 40.00, reward_in 0.74
# 1654 Episode in 109428 steps, reward_ex 34.00, reward_in 0.80
# 1655 Episode in 109484 steps, reward_ex 56.00, reward_in 1.51
# 1656 Episode in 109528 steps, reward_ex 44.00, reward_in 1.44
# 1657 Episode in 109562 steps, reward_ex 34.00, reward_in 1.37
# 1658 Episode in 109602 steps, reward_ex 40.00, reward_in 1.30
# 1659 Episode in 109650 steps, reward_ex 48.00, reward_in 1.43
# 1660 Episode in 109685 steps, reward_ex 35.00, reward_in 0.99
# 1661 Episode in 109723 steps, reward_ex 38.00, reward_in 1.73
# 1662 Episode in 109771 steps, reward_ex 48.00, reward_in 1.19
# 1663 Episode in 109829 steps, reward_ex 58.00, reward_in 3.57
# 1664 Episode in 109889 steps, reward_ex 60.00, reward_in 1.61
# 1665 Episode in 109925 steps, reward_ex 36.00, reward_in 0.98
# 1666 Episode in 109983 steps, reward_ex 58.00, reward_in 3.75
# 1667 Episode in 110047 steps, reward_ex 64.00, reward_in 2.01
# 1668 Episode in 110104 steps, reward_ex 57.00, reward_in 2.96
# 1669 Episode in 110150 steps, reward_ex 46.00, reward_in 2.38
# 1670 Episode in 110201 steps, reward_ex 51.00, reward_in 2.64
# 1671 Episode in 110235 steps, reward_ex 34.00, reward_in 1.41
# 1672 Episode in 110276 steps, reward_ex 41.00, reward_in 1.55
# 1673 Episode in 110317 steps, reward_ex 41.00, reward_in 1.54
# 1674 Episode in 110369 steps, reward_ex 52.00, reward_in 3.93
# 1675 Episode in 110410 steps, reward_ex 41.00, reward_in 1.69
# 1676 Episode in 110455 steps, reward_ex 45.00, reward_in 1.95
# 1677 Episode in 110494 steps, reward_ex 39.00, reward_in 1.43
# 1678 Episode in 110550 steps, reward_ex 56.00, reward_in 2.54
# 1679 Episode in 110587 steps, reward_ex 37.00, reward_in 1.59
# 1680 Episode in 110631 steps, reward_ex 44.00, reward_in 0.96
# 1681 Episode in 110679 steps, reward_ex 48.00, reward_in 1.25
# 1682 Episode in 110753 steps, reward_ex 74.00, reward_in 3.99
# 1683 Episode in 110789 steps, reward_ex 36.00, reward_in 1.25
# 1684 Episode in 110831 steps, reward_ex 42.00, reward_in 1.33
# 1685 Episode in 110865 steps, reward_ex 34.00, reward_in 1.11
# 1686 Episode in 110903 steps, reward_ex 38.00, reward_in 1.34
# 1687 Episode in 110954 steps, reward_ex 51.00, reward_in 5.94
# 1688 Episode in 110996 steps, reward_ex 42.00, reward_in 2.67
# 1689 Episode in 111046 steps, reward_ex 50.00, reward_in 2.91
# 1690 Episode in 111090 steps, reward_ex 44.00, reward_in 3.08
# 1691 Episode in 111136 steps, reward_ex 46.00, reward_in 2.22
# 1692 Episode in 111184 steps, reward_ex 48.00, reward_in 1.93
# 1693 Episode in 111221 steps, reward_ex 37.00, reward_in 1.46
# 1694 Episode in 111261 steps, reward_ex 40.00, reward_in 0.92
# 1695 Episode in 111305 steps, reward_ex 44.00, reward_in 2.01
# 1696 Episode in 111345 steps, reward_ex 40.00, reward_in 1.04
# 1697 Episode in 111392 steps, reward_ex 47.00, reward_in 1.47
# 1698 Episode in 111425 steps, reward_ex 33.00, reward_in 0.77
# 1699 Episode in 111463 steps, reward_ex 38.00, reward_in 0.92
# 1700 Episode in 111505 steps, reward_ex 42.00, reward_in 1.00
# 1701 Episode in 111555 steps, reward_ex 50.00, reward_in 4.19
# 1702 Episode in 111590 steps, reward_ex 35.00, reward_in 0.93
# 1703 Episode in 111643 steps, reward_ex 53.00, reward_in 3.82
# 1704 Episode in 111688 steps, reward_ex 45.00, reward_in 2.41
# 1705 Episode in 111728 steps, reward_ex 40.00, reward_in 3.37
# 1706 Episode in 111790 steps, reward_ex 62.00, reward_in 3.19
# 1707 Episode in 111830 steps, reward_ex 40.00, reward_in 1.17
# 1708 Episode in 111887 steps, reward_ex 57.00, reward_in 2.64
# 1709 Episode in 111929 steps, reward_ex 42.00, reward_in 1.57
# 1710 Episode in 111965 steps, reward_ex 36.00, reward_in 2.77
# 1711 Episode in 112029 steps, reward_ex 64.00, reward_in 3.16
# 1712 Episode in 112070 steps, reward_ex 41.00, reward_in 3.09
# 1713 Episode in 112124 steps, reward_ex 54.00, reward_in 3.35
# 1714 Episode in 112180 steps, reward_ex 56.00, reward_in 1.82
# 1715 Episode in 112218 steps, reward_ex 38.00, reward_in 1.19
# 1716 Episode in 112272 steps, reward_ex 54.00, reward_in 3.62
# 1717 Episode in 112326 steps, reward_ex 54.00, reward_in 2.97
# 1718 Episode in 112382 steps, reward_ex 56.00, reward_in 2.35
# 1719 Episode in 112426 steps, reward_ex 44.00, reward_in 1.87
# 1720 Episode in 112462 steps, reward_ex 36.00, reward_in 1.24
# 1721 Episode in 112510 steps, reward_ex 48.00, reward_in 1.83
# 1722 Episode in 112551 steps, reward_ex 41.00, reward_in 1.60
# 1723 Episode in 112605 steps, reward_ex 54.00, reward_in 2.44
# 1724 Episode in 112661 steps, reward_ex 56.00, reward_in 2.88
# 1725 Episode in 112699 steps, reward_ex 38.00, reward_in 1.74
# 1726 Episode in 112745 steps, reward_ex 46.00, reward_in 11.47
# 1727 Episode in 112798 steps, reward_ex 53.00, reward_in 2.90
# 1728 Episode in 112850 steps, reward_ex 52.00, reward_in 2.41
# 1729 Episode in 112885 steps, reward_ex 35.00, reward_in 1.52
# 1730 Episode in 112939 steps, reward_ex 54.00, reward_in 3.86
# 1731 Episode in 112979 steps, reward_ex 40.00, reward_in 2.98
# 1732 Episode in 113025 steps, reward_ex 46.00, reward_in 3.57
# 1733 Episode in 113067 steps, reward_ex 42.00, reward_in 4.44
# 1734 Episode in 113113 steps, reward_ex 46.00, reward_in 2.33
# 1735 Episode in 113154 steps, reward_ex 41.00, reward_in 2.35
# 1736 Episode in 113194 steps, reward_ex 40.00, reward_in 1.39
# 1737 Episode in 113232 steps, reward_ex 38.00, reward_in 1.49
# 1738 Episode in 113272 steps, reward_ex 40.00, reward_in 1.37
# 1739 Episode in 113318 steps, reward_ex 46.00, reward_in 2.09
# 1740 Episode in 113353 steps, reward_ex 35.00, reward_in 1.82
# 1741 Episode in 113421 steps, reward_ex 68.00, reward_in 7.48
# 1742 Episode in 113467 steps, reward_ex 46.00, reward_in 2.25
# 1743 Episode in 113503 steps, reward_ex 36.00, reward_in 2.74
# 1744 Episode in 113544 steps, reward_ex 41.00, reward_in 2.49
# 1745 Episode in 113586 steps, reward_ex 42.00, reward_in 1.40
# 1746 Episode in 113634 steps, reward_ex 48.00, reward_in 2.65
# 1747 Episode in 113695 steps, reward_ex 61.00, reward_in 2.25
# 1748 Episode in 113745 steps, reward_ex 50.00, reward_in 1.21
# 1749 Episode in 113793 steps, reward_ex 48.00, reward_in 1.18
# 1750 Episode in 113841 steps, reward_ex 48.00, reward_in 1.34
# 1751 Episode in 113887 steps, reward_ex 46.00, reward_in 2.43
# 1752 Episode in 113931 steps, reward_ex 44.00, reward_in 1.28
# 1753 Episode in 113978 steps, reward_ex 47.00, reward_in 1.24
# 1754 Episode in 114024 steps, reward_ex 46.00, reward_in 1.24
# 1755 Episode in 114068 steps, reward_ex 44.00, reward_in 1.38
# 1756 Episode in 114118 steps, reward_ex 50.00, reward_in 1.45
# 1757 Episode in 114168 steps, reward_ex 50.00, reward_in 1.96
# 1758 Episode in 114210 steps, reward_ex 42.00, reward_in 0.92
# 1759 Episode in 114254 steps, reward_ex 44.00, reward_in 0.92
# 1760 Episode in 114292 steps, reward_ex 38.00, reward_in 1.75
# 1761 Episode in 114328 steps, reward_ex 36.00, reward_in 1.00
# 1762 Episode in 114363 steps, reward_ex 35.00, reward_in 1.45
# 1763 Episode in 114403 steps, reward_ex 40.00, reward_in 1.17
# 1764 Episode in 114440 steps, reward_ex 37.00, reward_in 1.19
# 1765 Episode in 114484 steps, reward_ex 44.00, reward_in 1.58
# 1766 Episode in 114532 steps, reward_ex 48.00, reward_in 1.71
# 1767 Episode in 114585 steps, reward_ex 53.00, reward_in 2.97
# 1768 Episode in 114665 steps, reward_ex 80.00, reward_in 23.70
# 1769 Episode in 114708 steps, reward_ex 43.00, reward_in 3.02
# 1770 Episode in 114763 steps, reward_ex 55.00, reward_in 7.61
# 1771 Episode in 114809 steps, reward_ex 46.00, reward_in 3.78
# 1772 Episode in 114877 steps, reward_ex 68.00, reward_in 6.54
# 1773 Episode in 114934 steps, reward_ex 57.00, reward_in 1.70
# 1774 Episode in 114981 steps, reward_ex 47.00, reward_in 2.32
# 1775 Episode in 115021 steps, reward_ex 40.00, reward_in 1.18
# 1776 Episode in 115061 steps, reward_ex 40.00, reward_in 2.09
# 1777 Episode in 115110 steps, reward_ex 49.00, reward_in 2.29
# 1778 Episode in 115194 steps, reward_ex 84.00, reward_in 4.69
# 1779 Episode in 115240 steps, reward_ex 46.00, reward_in 1.53
# 1780 Episode in 115297 steps, reward_ex 57.00, reward_in 2.26
# 1781 Episode in 115339 steps, reward_ex 42.00, reward_in 1.64
# 1782 Episode in 115426 steps, reward_ex 87.00, reward_in 4.89

# %%
plt.figure(figsize=(15, 5))
plt.title('Reward')
plt.plot(ep_rewards)
plt.figure(figsize=(15, 5))
plt.title('Loss')
plt.plot(losses)
plt.figure(figsize=(15, 5))
plt.title('m_Loss')
plt.plot(m_losses)
plt.figure(figsize=(15, 5))
plt.title('f_Loss')
plt.plot(f_losses)
plt.show()

# %%
[
    ('CartPole-v0', 161, 32, 256),
    ('CartPole-v1', 162, 32, 256),
    ('MountainCar-v0', 660),
    ('LunarLander-v2', 260)
]
