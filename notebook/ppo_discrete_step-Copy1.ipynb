# %%
from collections import deque
from copy import deepcopy

import gym
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions import Categorical
from torch.utils.data import DataLoader

# %%
SEED = 1
BATCH_SIZE = 4
LR = 0.00025
EPOCHS = 4
CLIP = 0.1
ALPHA = 0.0001
GAMMA = 0.99
LAMBDA = 0.95
ENT_COEF = 0.001
V_CLIP = False

# set device
use_cuda = torch.cuda.is_available()
print('cuda:', use_cuda)
device = torch.device('cuda' if use_cuda else 'cpu')

# random seed
np.random.seed(SEED)
torch.manual_seed(SEED)
if use_cuda:
    torch.cuda.manual_seed_all(SEED)
# Out:
# cuda: True

# %%
class ActorCriticNet(nn.Module):
    def __init__(self, obs_space, action_space):
        super().__init__()

        self.head = nn.Sequential(
            nn.Linear(obs_space, 256),
            nn.SELU()
        )

        self.pol = nn.Sequential(
            nn.Linear(256, 256),
            nn.SELU(),
            nn.Linear(256, action_space)
        )
        
        self.val = nn.Sequential(
            nn.Linear(256, 256),
            nn.SELU(),
            nn.Linear(256, 1)
        )
        
        self.log_softmax = nn.LogSoftmax(dim=-1)

    def forward(self, x):
        out = self.head(x)
        logit = self.pol(out).reshape(out.shape[0], -1)
        log_p = self.log_softmax(logit)
        v = self.val(out).reshape(out.shape[0], 1)

        return log_p, v

# %%
losses = []


def learn(net, old_net, optimizer, train_memory):
    net.train()
    old_net.train()    
    dataloader = DataLoader(train_memory,
                            batch_size=BATCH_SIZE,
                            shuffle=True,
                            pin_memory=use_cuda)

    for i in range(EPOCHS):
        for (s, a, _s, ret, adv) in dataloader:
            s_batch = s.to(device).float()
            a_batch = a.to(device).long()
            _s_batch = _s.to(device).float()
            ret_batch = ret.to(device).float()
            adv_batch = adv.to(device).float()

            with torch.no_grad():
                log_p_batch_old, v_batch_old = old_net(s_batch)
                log_p_acting_old = log_p_batch_old[range(BATCH_SIZE), a_batch]

            log_p_batch, v_batch = net(s_batch)
            log_p_acting = log_p_batch[range(BATCH_SIZE), a_batch]
            p_ratio = (log_p_acting - log_p_acting_old).exp()
            p_ratio_clip = torch.clamp(p_ratio, 1. - CLIP, 1. + CLIP)
            p_loss = torch.min(p_ratio * adv_batch, p_ratio_clip * adv_batch).mean()
            if V_CLIP:
                v_clip = v_batch_old + torch.clamp(v_batch - v_batch_old, -CLIP, CLIP)
                v_loss1 = (ret_batch - v_clip).pow(2)
                v_loss2 = (ret_batch - v_batch).pow(2)
                v_loss = torch.max(v_loss1, v_loss2).mean()
            else:
                v_loss = (ret_batch - v_batch).pow(2).mean()
            entropy = -(log_p_batch.exp() * log_p_batch).sum(dim=1).mean()

            # loss
            loss = -(p_loss - v_loss + ENT_COEF * entropy)
            losses.append(loss)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            


def get_action_and_value(obs, net):
    net.eval()
    with torch.no_grad():
        state = torch.tensor([obs]).to(device).float()
        log_p, v = net(state)
        m = Categorical(log_p.exp())
        action = m.sample()

    return action.item(), v.item()


def compute_adv_with_gae(rewards, values, roll_memory):
    rew = np.array(rewards, 'float')
    val = np.array(values[:-1], 'float')
    _val = np.array(values[1:], 'float')
    delta = rew + GAMMA * _val - val
    dis_r = np.array([GAMMA**(i) * r for i, r in enumerate(rewards)], 'float')
    gae_dt = np.array([(GAMMA * LAMBDA)**(i) * dt for i, dt in enumerate(delta.tolist())], 'float')
    for i, data in enumerate(roll_memory):
        data.append(sum(dis_r[i:] / GAMMA**(i)))
        data.append(sum(gae_dt[i:] / (GAMMA * LAMBDA)**(i)))

    return roll_memory

# %% [markdown]
# ## Main

# %%
# make an environment
# env = gym.make('CartPole-v0')
# env = gym.make('CartPole-v1')
env = gym.make('MountainCar-v0')
# env = gym.make('LunarLander-v2')

env.seed(SEED)
obs_space = env.observation_space.shape[0]
action_space = env.action_space.n

# hyperparameter
n_episodes = 1000
roll_len = 128
n_eval = env.spec.trials

# global values
steps = 0
learn_steps = 0
ep_rewards = []
reward_eval = deque(maxlen=n_eval)
is_rollout = False
is_solved = False

# make memories
net_memory = deque(maxlen=2)
train_memory = []
roll_memory = []
rewards = []
values = []

# make nerual networks
net = ActorCriticNet(obs_space, action_space).to(device) 
old_net = deepcopy(net)
net_memory.appendleft(net.state_dict())

# make a optimizer
optimizer = optim.Adam(net.parameters(), lr=LR, eps=1e-5)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
env.spec.max_episode_steps
# Out:
# 200

# %%
env.spec.trials
# Out:
# 100

# %%
env.spec.reward_threshold
# Out:
# -110.0

# %%
# play
for i in range(1, n_episodes + 1):
    obs = env.reset()
    done = False
    ep_reward = 0
    while not done:
        env.render()
        action, value = get_action_and_value(obs, net)
        _obs, reward, done, _ = env.step(action)
        
        # store
        if done:
            value = 0.
        roll_memory.append([obs, action, _obs])
        rewards.append(reward)
        values.append(value)
        
        obs = _obs
        steps += 1
        ep_reward += reward
        
        if done or steps % roll_len == 0:
            if done:
                _value = 0.
            else:
                _, _value = get_action_and_value(_obs, net)

            values.append(_value)
            train_memory.extend(compute_adv_with_gae(rewards, values, roll_memory))
            rewards.clear()
            values.clear()
            roll_memory.clear()
            
        if steps % roll_len == 0:
            net_memory.appendleft(net.state_dict())
            old_net.load_state_dict(net_memory.pop())
            learn(net, old_net, optimizer, train_memory)
            train_memory.clear()
            learn_steps += 1
    
    if done:        
        ep_rewards.append(ep_reward)
        print('{:3} Episode in {:5} steps, reward {:.2f}'.format(
            i, steps, ep_reward))

        if len(ep_rewards) >= n_eval:
            if np.mean(list(reversed(ep_rewards))[: n_eval]) >= env.spec.reward_threshold:
                print('\n{} is sloved! {:3} Episode in {:3} steps'.format(
                    env.spec.id, i, steps))
                torch.save(old_net.state_dict(),
                           f'./test/saved_models/{env.spec.id}_ep{i}_clear_model_ppo_st.pt')
                break
env.close()
# Out:
#   1 Episode in   200 steps, reward -200.00
#   2 Episode in   400 steps, reward -200.00
#   3 Episode in   600 steps, reward -200.00
#   4 Episode in   800 steps, reward -200.00
#   5 Episode in  1000 steps, reward -200.00
#   6 Episode in  1200 steps, reward -200.00
#   7 Episode in  1400 steps, reward -200.00
#   8 Episode in  1600 steps, reward -200.00
#   9 Episode in  1800 steps, reward -200.00
#  10 Episode in  2000 steps, reward -200.00
#  11 Episode in  2200 steps, reward -200.00
#  12 Episode in  2400 steps, reward -200.00
#  13 Episode in  2600 steps, reward -200.00
#  14 Episode in  2800 steps, reward -200.00
#  15 Episode in  3000 steps, reward -200.00
#  16 Episode in  3200 steps, reward -200.00
#  17 Episode in  3400 steps, reward -200.00
#  18 Episode in  3600 steps, reward -200.00
#  19 Episode in  3800 steps, reward -200.00
#  20 Episode in  4000 steps, reward -200.00
#  21 Episode in  4200 steps, reward -200.00
#  22 Episode in  4400 steps, reward -200.00
#  23 Episode in  4600 steps, reward -200.00
#  24 Episode in  4800 steps, reward -200.00
#  25 Episode in  5000 steps, reward -200.00
#  26 Episode in  5200 steps, reward -200.00
#  27 Episode in  5400 steps, reward -200.00
#  28 Episode in  5600 steps, reward -200.00
#  29 Episode in  5800 steps, reward -200.00
#  30 Episode in  6000 steps, reward -200.00
#  31 Episode in  6200 steps, reward -200.00
#  32 Episode in  6400 steps, reward -200.00
#  33 Episode in  6600 steps, reward -200.00
#  34 Episode in  6800 steps, reward -200.00
#  35 Episode in  7000 steps, reward -200.00
#  36 Episode in  7200 steps, reward -200.00
#  37 Episode in  7400 steps, reward -200.00
#  38 Episode in  7600 steps, reward -200.00
#  39 Episode in  7800 steps, reward -200.00
#  40 Episode in  8000 steps, reward -200.00
#  41 Episode in  8200 steps, reward -200.00
#  42 Episode in  8400 steps, reward -200.00
#  43 Episode in  8600 steps, reward -200.00
#  44 Episode in  8800 steps, reward -200.00
#  45 Episode in  9000 steps, reward -200.00
#  46 Episode in  9200 steps, reward -200.00
#  47 Episode in  9400 steps, reward -200.00
#  48 Episode in  9600 steps, reward -200.00
#  49 Episode in  9800 steps, reward -200.00
#  50 Episode in 10000 steps, reward -200.00
#  51 Episode in 10200 steps, reward -200.00
#  52 Episode in 10400 steps, reward -200.00
#  53 Episode in 10600 steps, reward -200.00
#  54 Episode in 10800 steps, reward -200.00
#  55 Episode in 11000 steps, reward -200.00
#  56 Episode in 11200 steps, reward -200.00
#  57 Episode in 11400 steps, reward -200.00
#  58 Episode in 11600 steps, reward -200.00
#  59 Episode in 11800 steps, reward -200.00
#  60 Episode in 12000 steps, reward -200.00
#  61 Episode in 12200 steps, reward -200.00
#  62 Episode in 12400 steps, reward -200.00
#  63 Episode in 12600 steps, reward -200.00
#  64 Episode in 12800 steps, reward -200.00
#  65 Episode in 13000 steps, reward -200.00
#  66 Episode in 13200 steps, reward -200.00
#  67 Episode in 13400 steps, reward -200.00
#  68 Episode in 13600 steps, reward -200.00
#  69 Episode in 13800 steps, reward -200.00
#  70 Episode in 14000 steps, reward -200.00
#  71 Episode in 14200 steps, reward -200.00
#  72 Episode in 14400 steps, reward -200.00
#  73 Episode in 14600 steps, reward -200.00
#  74 Episode in 14800 steps, reward -200.00
#  75 Episode in 15000 steps, reward -200.00
#  76 Episode in 15200 steps, reward -200.00
#  77 Episode in 15400 steps, reward -200.00
#  78 Episode in 15600 steps, reward -200.00
#  79 Episode in 15800 steps, reward -200.00
#  80 Episode in 16000 steps, reward -200.00
#  81 Episode in 16200 steps, reward -200.00
#  82 Episode in 16400 steps, reward -200.00
#  83 Episode in 16600 steps, reward -200.00
#  84 Episode in 16800 steps, reward -200.00
#  85 Episode in 17000 steps, reward -200.00
#  86 Episode in 17200 steps, reward -200.00
#  87 Episode in 17400 steps, reward -200.00
#  88 Episode in 17600 steps, reward -200.00
#  89 Episode in 17800 steps, reward -200.00
#  90 Episode in 18000 steps, reward -200.00
#  91 Episode in 18200 steps, reward -200.00
#  92 Episode in 18400 steps, reward -200.00
#  93 Episode in 18600 steps, reward -200.00
#  94 Episode in 18800 steps, reward -200.00
#  95 Episode in 19000 steps, reward -200.00
#  96 Episode in 19200 steps, reward -200.00
#  97 Episode in 19400 steps, reward -200.00
#  98 Episode in 19600 steps, reward -200.00
#  99 Episode in 19800 steps, reward -200.00
# 100 Episode in 20000 steps, reward -200.00
# 101 Episode in 20200 steps, reward -200.00
# 102 Episode in 20400 steps, reward -200.00
# 103 Episode in 20600 steps, reward -200.00
# 104 Episode in 20800 steps, reward -200.00
# 105 Episode in 21000 steps, reward -200.00
# 106 Episode in 21200 steps, reward -200.00
# 107 Episode in 21400 steps, reward -200.00
# 108 Episode in 21600 steps, reward -200.00
# 109 Episode in 21800 steps, reward -200.00
# 110 Episode in 22000 steps, reward -200.00
# 111 Episode in 22200 steps, reward -200.00
# 112 Episode in 22400 steps, reward -200.00
# 113 Episode in 22600 steps, reward -200.00
# 114 Episode in 22800 steps, reward -200.00
# 115 Episode in 23000 steps, reward -200.00
# 116 Episode in 23200 steps, reward -200.00
# 117 Episode in 23400 steps, reward -200.00
# 118 Episode in 23600 steps, reward -200.00
# 119 Episode in 23800 steps, reward -200.00
# 120 Episode in 24000 steps, reward -200.00
# 121 Episode in 24200 steps, reward -200.00
# 122 Episode in 24400 steps, reward -200.00
# 123 Episode in 24600 steps, reward -200.00
# 124 Episode in 24800 steps, reward -200.00
# 125 Episode in 25000 steps, reward -200.00
# 126 Episode in 25200 steps, reward -200.00
# 127 Episode in 25400 steps, reward -200.00
# 128 Episode in 25600 steps, reward -200.00
# 129 Episode in 25800 steps, reward -200.00
# 130 Episode in 26000 steps, reward -200.00
# 131 Episode in 26200 steps, reward -200.00
# 132 Episode in 26400 steps, reward -200.00
# 133 Episode in 26600 steps, reward -200.00
# 134 Episode in 26800 steps, reward -200.00
# 135 Episode in 27000 steps, reward -200.00
# 136 Episode in 27200 steps, reward -200.00
# 137 Episode in 27400 steps, reward -200.00
# 138 Episode in 27600 steps, reward -200.00
# 139 Episode in 27800 steps, reward -200.00
# 140 Episode in 28000 steps, reward -200.00
# 141 Episode in 28200 steps, reward -200.00
# 142 Episode in 28400 steps, reward -200.00
# 143 Episode in 28600 steps, reward -200.00
# 144 Episode in 28800 steps, reward -200.00
# 145 Episode in 29000 steps, reward -200.00
# 146 Episode in 29200 steps, reward -200.00
# 147 Episode in 29400 steps, reward -200.00
# 148 Episode in 29600 steps, reward -200.00
# 149 Episode in 29800 steps, reward -200.00
# 150 Episode in 30000 steps, reward -200.00
# 151 Episode in 30200 steps, reward -200.00
# 152 Episode in 30400 steps, reward -200.00
# 153 Episode in 30600 steps, reward -200.00
# 154 Episode in 30800 steps, reward -200.00
# 155 Episode in 31000 steps, reward -200.00
# 156 Episode in 31200 steps, reward -200.00
# 157 Episode in 31400 steps, reward -200.00
# 158 Episode in 31600 steps, reward -200.00
# 159 Episode in 31800 steps, reward -200.00
# 160 Episode in 32000 steps, reward -200.00
# 161 Episode in 32200 steps, reward -200.00
# 162 Episode in 32400 steps, reward -200.00
# 163 Episode in 32600 steps, reward -200.00
# 164 Episode in 32800 steps, reward -200.00
# 165 Episode in 33000 steps, reward -200.00
# 166 Episode in 33200 steps, reward -200.00
# 167 Episode in 33400 steps, reward -200.00
# 168 Episode in 33600 steps, reward -200.00
# 169 Episode in 33800 steps, reward -200.00
# 170 Episode in 34000 steps, reward -200.00
# 171 Episode in 34200 steps, reward -200.00
# 172 Episode in 34400 steps, reward -200.00
# 173 Episode in 34600 steps, reward -200.00
# 174 Episode in 34800 steps, reward -200.00
# 175 Episode in 35000 steps, reward -200.00
# 176 Episode in 35200 steps, reward -200.00
# 177 Episode in 35400 steps, reward -200.00
# 178 Episode in 35600 steps, reward -200.00
# 179 Episode in 35800 steps, reward -200.00
# 180 Episode in 36000 steps, reward -200.00
# 181 Episode in 36200 steps, reward -200.00
# 182 Episode in 36400 steps, reward -200.00
# 183 Episode in 36600 steps, reward -200.00
# 184 Episode in 36800 steps, reward -200.00
# 185 Episode in 37000 steps, reward -200.00
# 186 Episode in 37200 steps, reward -200.00
# 187 Episode in 37400 steps, reward -200.00
# 188 Episode in 37600 steps, reward -200.00
# 189 Episode in 37800 steps, reward -200.00
# 190 Episode in 38000 steps, reward -200.00
# 191 Episode in 38200 steps, reward -200.00
# 192 Episode in 38400 steps, reward -200.00
# 193 Episode in 38600 steps, reward -200.00
# 194 Episode in 38800 steps, reward -200.00
# 195 Episode in 39000 steps, reward -200.00
# 196 Episode in 39200 steps, reward -200.00
# 197 Episode in 39400 steps, reward -200.00
# 198 Episode in 39600 steps, reward -200.00
# 199 Episode in 39800 steps, reward -200.00
# 200 Episode in 40000 steps, reward -200.00
# 201 Episode in 40200 steps, reward -200.00
# 202 Episode in 40400 steps, reward -200.00
# 203 Episode in 40600 steps, reward -200.00
# 204 Episode in 40800 steps, reward -200.00
# 205 Episode in 41000 steps, reward -200.00
# 206 Episode in 41200 steps, reward -200.00
# 207 Episode in 41400 steps, reward -200.00
# 208 Episode in 41600 steps, reward -200.00
# 209 Episode in 41800 steps, reward -200.00
# 210 Episode in 42000 steps, reward -200.00
# 211 Episode in 42200 steps, reward -200.00
# 212 Episode in 42400 steps, reward -200.00
# 213 Episode in 42600 steps, reward -200.00
# 214 Episode in 42800 steps, reward -200.00
# 215 Episode in 43000 steps, reward -200.00
# 216 Episode in 43200 steps, reward -200.00
# 217 Episode in 43400 steps, reward -200.00
# 218 Episode in 43600 steps, reward -200.00
# 219 Episode in 43800 steps, reward -200.00
# 220 Episode in 44000 steps, reward -200.00
# 221 Episode in 44200 steps, reward -200.00
# 222 Episode in 44400 steps, reward -200.00
# 223 Episode in 44600 steps, reward -200.00
# 224 Episode in 44800 steps, reward -200.00
# 225 Episode in 45000 steps, reward -200.00
# 226 Episode in 45200 steps, reward -200.00
# 227 Episode in 45400 steps, reward -200.00
# 228 Episode in 45600 steps, reward -200.00
# 229 Episode in 45800 steps, reward -200.00
# 230 Episode in 46000 steps, reward -200.00
# 231 Episode in 46200 steps, reward -200.00
# 232 Episode in 46400 steps, reward -200.00
# 233 Episode in 46600 steps, reward -200.00
# 234 Episode in 46800 steps, reward -200.00
# 235 Episode in 47000 steps, reward -200.00
# 236 Episode in 47200 steps, reward -200.00
# 237 Episode in 47400 steps, reward -200.00
# 238 Episode in 47600 steps, reward -200.00
# 239 Episode in 47800 steps, reward -200.00
# 240 Episode in 48000 steps, reward -200.00
# 241 Episode in 48200 steps, reward -200.00
# 242 Episode in 48400 steps, reward -200.00
# 243 Episode in 48600 steps, reward -200.00
# 244 Episode in 48800 steps, reward -200.00
# 245 Episode in 49000 steps, reward -200.00
# 246 Episode in 49200 steps, reward -200.00
# 247 Episode in 49400 steps, reward -200.00
# 248 Episode in 49600 steps, reward -200.00
# 249 Episode in 49800 steps, reward -200.00
# 250 Episode in 50000 steps, reward -200.00
# 251 Episode in 50200 steps, reward -200.00
# 252 Episode in 50400 steps, reward -200.00
# 253 Episode in 50600 steps, reward -200.00
# 254 Episode in 50800 steps, reward -200.00
# 255 Episode in 51000 steps, reward -200.00
# 256 Episode in 51200 steps, reward -200.00
# 257 Episode in 51400 steps, reward -200.00
# 258 Episode in 51600 steps, reward -200.00
# 259 Episode in 51800 steps, reward -200.00
# 260 Episode in 52000 steps, reward -200.00
# 261 Episode in 52200 steps, reward -200.00
# 262 Episode in 52400 steps, reward -200.00
# 263 Episode in 52600 steps, reward -200.00
# 264 Episode in 52800 steps, reward -200.00
# 265 Episode in 53000 steps, reward -200.00
# 266 Episode in 53200 steps, reward -200.00
# 267 Episode in 53400 steps, reward -200.00
# 268 Episode in 53600 steps, reward -200.00
# 269 Episode in 53800 steps, reward -200.00
# 270 Episode in 54000 steps, reward -200.00
# 271 Episode in 54200 steps, reward -200.00
# 272 Episode in 54400 steps, reward -200.00
# 273 Episode in 54600 steps, reward -200.00
# 274 Episode in 54800 steps, reward -200.00
# 275 Episode in 55000 steps, reward -200.00
# 276 Episode in 55200 steps, reward -200.00
# 277 Episode in 55400 steps, reward -200.00
# 278 Episode in 55600 steps, reward -200.00
# 279 Episode in 55800 steps, reward -200.00
# 280 Episode in 56000 steps, reward -200.00
# 281 Episode in 56200 steps, reward -200.00
# 282 Episode in 56400 steps, reward -200.00
# 283 Episode in 56600 steps, reward -200.00
# 284 Episode in 56800 steps, reward -200.00
# 285 Episode in 57000 steps, reward -200.00
# 286 Episode in 57200 steps, reward -200.00
# 287 Episode in 57400 steps, reward -200.00
# 288 Episode in 57600 steps, reward -200.00
# 289 Episode in 57800 steps, reward -200.00
# 290 Episode in 58000 steps, reward -200.00
# 291 Episode in 58200 steps, reward -200.00
# 292 Episode in 58400 steps, reward -200.00
# 293 Episode in 58600 steps, reward -200.00
# 294 Episode in 58800 steps, reward -200.00
# 295 Episode in 59000 steps, reward -200.00
# 296 Episode in 59200 steps, reward -200.00
# 297 Episode in 59400 steps, reward -200.00
# 298 Episode in 59600 steps, reward -200.00
# 299 Episode in 59800 steps, reward -200.00
# 300 Episode in 60000 steps, reward -200.00
# 301 Episode in 60200 steps, reward -200.00
# 302 Episode in 60400 steps, reward -200.00
# 303 Episode in 60600 steps, reward -200.00
# 304 Episode in 60800 steps, reward -200.00
# 305 Episode in 61000 steps, reward -200.00
# 306 Episode in 61200 steps, reward -200.00
# 307 Episode in 61400 steps, reward -200.00
# 308 Episode in 61600 steps, reward -200.00
# 309 Episode in 61800 steps, reward -200.00
# 310 Episode in 62000 steps, reward -200.00
# 311 Episode in 62200 steps, reward -200.00
# 312 Episode in 62400 steps, reward -200.00
# 313 Episode in 62600 steps, reward -200.00
# 314 Episode in 62800 steps, reward -200.00
# 315 Episode in 63000 steps, reward -200.00
# 316 Episode in 63200 steps, reward -200.00
# 317 Episode in 63400 steps, reward -200.00
# 318 Episode in 63600 steps, reward -200.00
# 319 Episode in 63800 steps, reward -200.00
# 320 Episode in 64000 steps, reward -200.00
# 321 Episode in 64200 steps, reward -200.00
# 322 Episode in 64400 steps, reward -200.00
# 323 Episode in 64600 steps, reward -200.00
# 324 Episode in 64800 steps, reward -200.00
# 325 Episode in 65000 steps, reward -200.00
# 326 Episode in 65200 steps, reward -200.00
# 327 Episode in 65400 steps, reward -200.00
# 328 Episode in 65600 steps, reward -200.00
# 329 Episode in 65800 steps, reward -200.00
# 330 Episode in 66000 steps, reward -200.00
# 331 Episode in 66200 steps, reward -200.00
# 332 Episode in 66400 steps, reward -200.00
# 333 Episode in 66600 steps, reward -200.00
# 334 Episode in 66800 steps, reward -200.00
# 335 Episode in 67000 steps, reward -200.00
# 336 Episode in 67200 steps, reward -200.00
# 337 Episode in 67400 steps, reward -200.00
# 338 Episode in 67600 steps, reward -200.00
# 339 Episode in 67800 steps, reward -200.00
# 340 Episode in 68000 steps, reward -200.00
# 341 Episode in 68200 steps, reward -200.00
# 342 Episode in 68400 steps, reward -200.00
# 343 Episode in 68600 steps, reward -200.00
# 344 Episode in 68800 steps, reward -200.00
# 345 Episode in 69000 steps, reward -200.00
# 346 Episode in 69200 steps, reward -200.00
# 347 Episode in 69400 steps, reward -200.00
# 348 Episode in 69600 steps, reward -200.00
# 349 Episode in 69800 steps, reward -200.00
# 350 Episode in 70000 steps, reward -200.00
# 351 Episode in 70200 steps, reward -200.00
# 352 Episode in 70400 steps, reward -200.00
# 353 Episode in 70600 steps, reward -200.00
# 354 Episode in 70800 steps, reward -200.00
# 355 Episode in 71000 steps, reward -200.00
# 356 Episode in 71200 steps, reward -200.00
# 357 Episode in 71400 steps, reward -200.00
# 358 Episode in 71600 steps, reward -200.00
# 359 Episode in 71800 steps, reward -200.00
# 360 Episode in 72000 steps, reward -200.00
# 361 Episode in 72200 steps, reward -200.00
# 362 Episode in 72400 steps, reward -200.00
# 363 Episode in 72600 steps, reward -200.00
# 364 Episode in 72800 steps, reward -200.00
# 365 Episode in 73000 steps, reward -200.00
# 366 Episode in 73200 steps, reward -200.00
# 367 Episode in 73400 steps, reward -200.00
# 368 Episode in 73600 steps, reward -200.00
# 369 Episode in 73800 steps, reward -200.00
# 370 Episode in 74000 steps, reward -200.00
# 371 Episode in 74200 steps, reward -200.00
# 372 Episode in 74400 steps, reward -200.00
# 373 Episode in 74600 steps, reward -200.00
# 374 Episode in 74800 steps, reward -200.00
# 375 Episode in 75000 steps, reward -200.00
# 376 Episode in 75200 steps, reward -200.00
# 377 Episode in 75400 steps, reward -200.00
# 378 Episode in 75600 steps, reward -200.00
# 379 Episode in 75800 steps, reward -200.00
# 380 Episode in 76000 steps, reward -200.00
# 381 Episode in 76200 steps, reward -200.00
# 382 Episode in 76400 steps, reward -200.00
# 383 Episode in 76600 steps, reward -200.00
# 384 Episode in 76800 steps, reward -200.00
# 385 Episode in 77000 steps, reward -200.00
# 386 Episode in 77200 steps, reward -200.00
# 387 Episode in 77400 steps, reward -200.00
# 388 Episode in 77600 steps, reward -200.00
# 389 Episode in 77800 steps, reward -200.00
# 390 Episode in 78000 steps, reward -200.00
# 391 Episode in 78200 steps, reward -200.00
# 392 Episode in 78400 steps, reward -200.00
# 393 Episode in 78600 steps, reward -200.00
# 394 Episode in 78800 steps, reward -200.00
# 395 Episode in 79000 steps, reward -200.00
# 396 Episode in 79200 steps, reward -200.00
# 397 Episode in 79400 steps, reward -200.00
# 398 Episode in 79600 steps, reward -200.00
# 399 Episode in 79800 steps, reward -200.00
# 400 Episode in 80000 steps, reward -200.00
# 401 Episode in 80200 steps, reward -200.00
# 402 Episode in 80400 steps, reward -200.00
# 403 Episode in 80600 steps, reward -200.00
# 404 Episode in 80800 steps, reward -200.00
# 405 Episode in 81000 steps, reward -200.00
# 406 Episode in 81200 steps, reward -200.00
# 407 Episode in 81400 steps, reward -200.00
# 408 Episode in 81600 steps, reward -200.00
# 409 Episode in 81800 steps, reward -200.00
# 410 Episode in 82000 steps, reward -200.00
# 411 Episode in 82200 steps, reward -200.00
# 412 Episode in 82400 steps, reward -200.00
# 413 Episode in 82600 steps, reward -200.00
# 414 Episode in 82800 steps, reward -200.00
# 415 Episode in 83000 steps, reward -200.00
# 416 Episode in 83200 steps, reward -200.00
# 417 Episode in 83400 steps, reward -200.00
# 418 Episode in 83600 steps, reward -200.00
# 419 Episode in 83800 steps, reward -200.00
# 420 Episode in 84000 steps, reward -200.00
# 421 Episode in 84200 steps, reward -200.00
# 422 Episode in 84400 steps, reward -200.00
# 423 Episode in 84600 steps, reward -200.00
# 424 Episode in 84800 steps, reward -200.00
# 425 Episode in 85000 steps, reward -200.00
# 426 Episode in 85200 steps, reward -200.00
# 427 Episode in 85400 steps, reward -200.00
# 428 Episode in 85600 steps, reward -200.00
# 429 Episode in 85800 steps, reward -200.00
# 430 Episode in 86000 steps, reward -200.00
# 431 Episode in 86200 steps, reward -200.00
# 432 Episode in 86400 steps, reward -200.00
# 433 Episode in 86600 steps, reward -200.00
# 434 Episode in 86800 steps, reward -200.00
# 435 Episode in 87000 steps, reward -200.00
# 436 Episode in 87200 steps, reward -200.00
# 437 Episode in 87400 steps, reward -200.00
# 438 Episode in 87600 steps, reward -200.00
# 439 Episode in 87800 steps, reward -200.00
# 440 Episode in 88000 steps, reward -200.00
# 441 Episode in 88200 steps, reward -200.00
# 442 Episode in 88400 steps, reward -200.00
# 443 Episode in 88600 steps, reward -200.00
# 444 Episode in 88800 steps, reward -200.00
# 445 Episode in 89000 steps, reward -200.00
# 446 Episode in 89200 steps, reward -200.00
# 447 Episode in 89400 steps, reward -200.00
# 448 Episode in 89600 steps, reward -200.00
# 449 Episode in 89800 steps, reward -200.00
# 450 Episode in 90000 steps, reward -200.00
# 451 Episode in 90200 steps, reward -200.00
# 452 Episode in 90400 steps, reward -200.00
# 453 Episode in 90600 steps, reward -200.00
# 454 Episode in 90800 steps, reward -200.00
# 455 Episode in 91000 steps, reward -200.00
# 456 Episode in 91200 steps, reward -200.00
# 457 Episode in 91400 steps, reward -200.00
# 458 Episode in 91600 steps, reward -200.00
# 459 Episode in 91800 steps, reward -200.00
# 460 Episode in 92000 steps, reward -200.00
# 461 Episode in 92200 steps, reward -200.00
# 462 Episode in 92400 steps, reward -200.00
# 463 Episode in 92600 steps, reward -200.00
# 464 Episode in 92800 steps, reward -200.00
# 465 Episode in 93000 steps, reward -200.00
# 466 Episode in 93200 steps, reward -200.00
# 467 Episode in 93400 steps, reward -200.00
# 468 Episode in 93600 steps, reward -200.00
# 469 Episode in 93800 steps, reward -200.00
# 470 Episode in 94000 steps, reward -200.00
# 471 Episode in 94200 steps, reward -200.00
# 472 Episode in 94400 steps, reward -200.00
# 473 Episode in 94600 steps, reward -200.00
# 474 Episode in 94800 steps, reward -200.00
# 475 Episode in 95000 steps, reward -200.00
# 476 Episode in 95200 steps, reward -200.00
# 477 Episode in 95400 steps, reward -200.00
# 478 Episode in 95600 steps, reward -200.00
# 479 Episode in 95800 steps, reward -200.00
# 480 Episode in 96000 steps, reward -200.00
# 481 Episode in 96200 steps, reward -200.00
# 482 Episode in 96400 steps, reward -200.00
# 483 Episode in 96600 steps, reward -200.00
# 484 Episode in 96800 steps, reward -200.00
# 485 Episode in 97000 steps, reward -200.00
# 486 Episode in 97200 steps, reward -200.00
# 487 Episode in 97400 steps, reward -200.00
# 488 Episode in 97600 steps, reward -200.00
# 489 Episode in 97800 steps, reward -200.00
# 490 Episode in 98000 steps, reward -200.00
# 491 Episode in 98200 steps, reward -200.00
# 492 Episode in 98400 steps, reward -200.00
# 493 Episode in 98600 steps, reward -200.00
# 494 Episode in 98800 steps, reward -200.00
# 495 Episode in 99000 steps, reward -200.00
# 496 Episode in 99200 steps, reward -200.00
# 497 Episode in 99400 steps, reward -200.00
# 498 Episode in 99600 steps, reward -200.00
# 499 Episode in 99800 steps, reward -200.00
# 500 Episode in 100000 steps, reward -200.00
# 501 Episode in 100200 steps, reward -200.00
# 502 Episode in 100400 steps, reward -200.00
# 503 Episode in 100600 steps, reward -200.00
# 504 Episode in 100800 steps, reward -200.00
# 505 Episode in 101000 steps, reward -200.00
# 506 Episode in 101200 steps, reward -200.00
# 507 Episode in 101400 steps, reward -200.00
# 508 Episode in 101600 steps, reward -200.00
# 509 Episode in 101800 steps, reward -200.00
# 510 Episode in 102000 steps, reward -200.00
# 511 Episode in 102200 steps, reward -200.00
# 512 Episode in 102400 steps, reward -200.00
# 513 Episode in 102600 steps, reward -200.00
# 514 Episode in 102800 steps, reward -200.00
# 515 Episode in 103000 steps, reward -200.00
# 516 Episode in 103200 steps, reward -200.00
# 517 Episode in 103400 steps, reward -200.00
# 518 Episode in 103600 steps, reward -200.00
# 519 Episode in 103800 steps, reward -200.00
# 520 Episode in 104000 steps, reward -200.00
# 521 Episode in 104200 steps, reward -200.00
# 522 Episode in 104400 steps, reward -200.00
# 523 Episode in 104600 steps, reward -200.00
# 524 Episode in 104800 steps, reward -200.00
# 525 Episode in 105000 steps, reward -200.00
# 526 Episode in 105200 steps, reward -200.00
# 527 Episode in 105400 steps, reward -200.00
# 528 Episode in 105600 steps, reward -200.00
# 529 Episode in 105800 steps, reward -200.00
# 530 Episode in 106000 steps, reward -200.00
# 531 Episode in 106200 steps, reward -200.00
# 532 Episode in 106400 steps, reward -200.00
# 533 Episode in 106600 steps, reward -200.00
# 534 Episode in 106800 steps, reward -200.00
# 535 Episode in 107000 steps, reward -200.00
# 536 Episode in 107200 steps, reward -200.00
# 537 Episode in 107400 steps, reward -200.00
# 538 Episode in 107600 steps, reward -200.00
# 539 Episode in 107800 steps, reward -200.00
# 540 Episode in 108000 steps, reward -200.00
# 541 Episode in 108200 steps, reward -200.00
# 542 Episode in 108400 steps, reward -200.00
# 543 Episode in 108600 steps, reward -200.00
# 544 Episode in 108800 steps, reward -200.00
# 545 Episode in 109000 steps, reward -200.00
# 546 Episode in 109200 steps, reward -200.00
# 547 Episode in 109400 steps, reward -200.00
# 548 Episode in 109600 steps, reward -200.00
# 549 Episode in 109800 steps, reward -200.00
# 550 Episode in 110000 steps, reward -200.00
# 551 Episode in 110200 steps, reward -200.00
# 552 Episode in 110400 steps, reward -200.00
# 553 Episode in 110600 steps, reward -200.00
# 554 Episode in 110800 steps, reward -200.00
# 555 Episode in 111000 steps, reward -200.00
# 556 Episode in 111200 steps, reward -200.00
# 557 Episode in 111400 steps, reward -200.00
# 558 Episode in 111600 steps, reward -200.00
# 559 Episode in 111800 steps, reward -200.00
# 560 Episode in 112000 steps, reward -200.00
# 561 Episode in 112200 steps, reward -200.00
# 562 Episode in 112400 steps, reward -200.00
# 563 Episode in 112600 steps, reward -200.00
# 564 Episode in 112800 steps, reward -200.00
# 565 Episode in 113000 steps, reward -200.00
# 566 Episode in 113200 steps, reward -200.00
# 567 Episode in 113400 steps, reward -200.00
# 568 Episode in 113600 steps, reward -200.00
# 569 Episode in 113800 steps, reward -200.00
# 570 Episode in 114000 steps, reward -200.00
# 571 Episode in 114200 steps, reward -200.00
# 572 Episode in 114400 steps, reward -200.00
# 573 Episode in 114600 steps, reward -200.00
# 574 Episode in 114800 steps, reward -200.00
# 575 Episode in 115000 steps, reward -200.00
# 576 Episode in 115200 steps, reward -200.00
# 577 Episode in 115400 steps, reward -200.00
# 578 Episode in 115600 steps, reward -200.00
# 579 Episode in 115800 steps, reward -200.00
# 580 Episode in 116000 steps, reward -200.00
# 581 Episode in 116200 steps, reward -200.00
# 582 Episode in 116400 steps, reward -200.00
# 583 Episode in 116600 steps, reward -200.00
# 584 Episode in 116800 steps, reward -200.00
# 585 Episode in 117000 steps, reward -200.00
# 586 Episode in 117200 steps, reward -200.00
# 587 Episode in 117400 steps, reward -200.00
# 588 Episode in 117600 steps, reward -200.00
# 589 Episode in 117800 steps, reward -200.00
# 590 Episode in 118000 steps, reward -200.00
# 591 Episode in 118200 steps, reward -200.00
# 592 Episode in 118400 steps, reward -200.00
# 593 Episode in 118600 steps, reward -200.00
# 594 Episode in 118800 steps, reward -200.00
# 595 Episode in 119000 steps, reward -200.00
# 596 Episode in 119200 steps, reward -200.00
# 597 Episode in 119400 steps, reward -200.00
# 598 Episode in 119600 steps, reward -200.00
# 599 Episode in 119800 steps, reward -200.00
# 600 Episode in 120000 steps, reward -200.00
# 601 Episode in 120200 steps, reward -200.00
# 602 Episode in 120400 steps, reward -200.00
# 603 Episode in 120600 steps, reward -200.00
# 604 Episode in 120800 steps, reward -200.00
# 605 Episode in 121000 steps, reward -200.00
# 606 Episode in 121200 steps, reward -200.00
# 607 Episode in 121400 steps, reward -200.00
# 608 Episode in 121600 steps, reward -200.00
# 609 Episode in 121800 steps, reward -200.00
# 610 Episode in 122000 steps, reward -200.00
# 611 Episode in 122200 steps, reward -200.00
# 612 Episode in 122400 steps, reward -200.00
# 613 Episode in 122600 steps, reward -200.00
# 614 Episode in 122800 steps, reward -200.00
# 615 Episode in 123000 steps, reward -200.00
# 616 Episode in 123200 steps, reward -200.00
# 617 Episode in 123400 steps, reward -200.00
# 618 Episode in 123600 steps, reward -200.00
# 619 Episode in 123800 steps, reward -200.00
# 620 Episode in 124000 steps, reward -200.00
# 621 Episode in 124200 steps, reward -200.00
# 622 Episode in 124400 steps, reward -200.00
# 623 Episode in 124600 steps, reward -200.00
# 624 Episode in 124800 steps, reward -200.00
# 625 Episode in 125000 steps, reward -200.00
# 626 Episode in 125200 steps, reward -200.00
# 627 Episode in 125400 steps, reward -200.00
# 628 Episode in 125600 steps, reward -200.00
# 629 Episode in 125800 steps, reward -200.00
# 630 Episode in 126000 steps, reward -200.00
# 631 Episode in 126200 steps, reward -200.00
# 632 Episode in 126400 steps, reward -200.00
# 633 Episode in 126600 steps, reward -200.00
# 634 Episode in 126800 steps, reward -200.00
# 635 Episode in 127000 steps, reward -200.00
# 636 Episode in 127200 steps, reward -200.00
# 637 Episode in 127400 steps, reward -200.00
# 638 Episode in 127600 steps, reward -200.00
# 639 Episode in 127800 steps, reward -200.00
# 640 Episode in 128000 steps, reward -200.00
# 641 Episode in 128200 steps, reward -200.00
# 642 Episode in 128400 steps, reward -200.00
# 643 Episode in 128600 steps, reward -200.00
# 644 Episode in 128800 steps, reward -200.00
# 645 Episode in 129000 steps, reward -200.00
# 646 Episode in 129200 steps, reward -200.00
# 647 Episode in 129400 steps, reward -200.00
# 648 Episode in 129600 steps, reward -200.00
# 649 Episode in 129800 steps, reward -200.00
# 650 Episode in 130000 steps, reward -200.00
# 651 Episode in 130200 steps, reward -200.00
# 652 Episode in 130400 steps, reward -200.00
# 653 Episode in 130600 steps, reward -200.00
# 654 Episode in 130800 steps, reward -200.00
# 655 Episode in 131000 steps, reward -200.00
# 656 Episode in 131200 steps, reward -200.00
# 657 Episode in 131400 steps, reward -200.00
# 658 Episode in 131600 steps, reward -200.00
# 659 Episode in 131800 steps, reward -200.00
# 660 Episode in 132000 steps, reward -200.00
# 661 Episode in 132200 steps, reward -200.00
# 662 Episode in 132400 steps, reward -200.00
# 663 Episode in 132600 steps, reward -200.00
# 664 Episode in 132800 steps, reward -200.00
# 665 Episode in 133000 steps, reward -200.00
# 666 Episode in 133200 steps, reward -200.00
# 667 Episode in 133400 steps, reward -200.00
# 668 Episode in 133600 steps, reward -200.00
# 669 Episode in 133800 steps, reward -200.00
# 670 Episode in 134000 steps, reward -200.00
# 671 Episode in 134200 steps, reward -200.00
# 672 Episode in 134400 steps, reward -200.00
# 673 Episode in 134600 steps, reward -200.00
# 674 Episode in 134800 steps, reward -200.00
# 675 Episode in 135000 steps, reward -200.00
# 676 Episode in 135200 steps, reward -200.00
# 677 Episode in 135400 steps, reward -200.00
# 678 Episode in 135600 steps, reward -200.00
# 679 Episode in 135800 steps, reward -200.00
# 680 Episode in 136000 steps, reward -200.00
# 681 Episode in 136200 steps, reward -200.00
# 682 Episode in 136400 steps, reward -200.00
# 683 Episode in 136600 steps, reward -200.00
# 684 Episode in 136800 steps, reward -200.00
# 685 Episode in 137000 steps, reward -200.00
# 686 Episode in 137200 steps, reward -200.00
# 687 Episode in 137400 steps, reward -200.00
# 688 Episode in 137600 steps, reward -200.00
# 689 Episode in 137800 steps, reward -200.00
# 690 Episode in 138000 steps, reward -200.00
# 691 Episode in 138200 steps, reward -200.00
# 692 Episode in 138400 steps, reward -200.00
# 693 Episode in 138600 steps, reward -200.00
# 694 Episode in 138800 steps, reward -200.00
# 695 Episode in 139000 steps, reward -200.00
# 696 Episode in 139200 steps, reward -200.00
# 697 Episode in 139400 steps, reward -200.00
# 698 Episode in 139600 steps, reward -200.00
# 699 Episode in 139800 steps, reward -200.00
# 700 Episode in 140000 steps, reward -200.00
# 701 Episode in 140200 steps, reward -200.00
# 702 Episode in 140400 steps, reward -200.00
# 703 Episode in 140600 steps, reward -200.00
# 704 Episode in 140800 steps, reward -200.00
# 705 Episode in 141000 steps, reward -200.00
# 706 Episode in 141200 steps, reward -200.00
# 707 Episode in 141400 steps, reward -200.00
# 708 Episode in 141600 steps, reward -200.00
# 709 Episode in 141800 steps, reward -200.00
# 710 Episode in 142000 steps, reward -200.00
# 711 Episode in 142200 steps, reward -200.00
# 712 Episode in 142400 steps, reward -200.00
# 713 Episode in 142600 steps, reward -200.00
# 714 Episode in 142800 steps, reward -200.00
# 715 Episode in 143000 steps, reward -200.00
# 716 Episode in 143200 steps, reward -200.00
# 717 Episode in 143400 steps, reward -200.00
# 718 Episode in 143600 steps, reward -200.00
# 719 Episode in 143800 steps, reward -200.00
# 720 Episode in 144000 steps, reward -200.00
# 721 Episode in 144200 steps, reward -200.00
# 722 Episode in 144400 steps, reward -200.00
# 723 Episode in 144600 steps, reward -200.00
# 724 Episode in 144800 steps, reward -200.00
# 725 Episode in 145000 steps, reward -200.00
# 726 Episode in 145200 steps, reward -200.00
# 727 Episode in 145400 steps, reward -200.00
# 728 Episode in 145600 steps, reward -200.00
# 729 Episode in 145800 steps, reward -200.00
# 730 Episode in 146000 steps, reward -200.00
# 731 Episode in 146200 steps, reward -200.00
# 732 Episode in 146400 steps, reward -200.00
# 733 Episode in 146600 steps, reward -200.00
# 734 Episode in 146800 steps, reward -200.00
# 735 Episode in 147000 steps, reward -200.00
# 736 Episode in 147200 steps, reward -200.00
# 737 Episode in 147400 steps, reward -200.00
# 738 Episode in 147600 steps, reward -200.00
# 739 Episode in 147800 steps, reward -200.00
# 740 Episode in 148000 steps, reward -200.00
# 741 Episode in 148200 steps, reward -200.00
# 742 Episode in 148400 steps, reward -200.00
# 743 Episode in 148600 steps, reward -200.00
# 744 Episode in 148800 steps, reward -200.00
# 745 Episode in 149000 steps, reward -200.00
# 746 Episode in 149200 steps, reward -200.00
# 747 Episode in 149400 steps, reward -200.00
# 748 Episode in 149600 steps, reward -200.00
# 749 Episode in 149800 steps, reward -200.00
# 750 Episode in 150000 steps, reward -200.00
# 751 Episode in 150200 steps, reward -200.00
# 752 Episode in 150400 steps, reward -200.00
# 753 Episode in 150600 steps, reward -200.00
# 754 Episode in 150800 steps, reward -200.00
# 755 Episode in 151000 steps, reward -200.00
# 756 Episode in 151200 steps, reward -200.00
# 757 Episode in 151400 steps, reward -200.00
# 758 Episode in 151600 steps, reward -200.00
# 759 Episode in 151800 steps, reward -200.00
# 760 Episode in 152000 steps, reward -200.00
# 761 Episode in 152200 steps, reward -200.00
# 762 Episode in 152400 steps, reward -200.00
# 763 Episode in 152600 steps, reward -200.00
# 764 Episode in 152800 steps, reward -200.00
# 765 Episode in 153000 steps, reward -200.00
# 766 Episode in 153200 steps, reward -200.00
# 767 Episode in 153400 steps, reward -200.00
# 768 Episode in 153600 steps, reward -200.00
# 769 Episode in 153800 steps, reward -200.00
# 770 Episode in 154000 steps, reward -200.00
# 771 Episode in 154200 steps, reward -200.00
# 772 Episode in 154400 steps, reward -200.00
# 773 Episode in 154600 steps, reward -200.00
# 774 Episode in 154800 steps, reward -200.00
# 775 Episode in 155000 steps, reward -200.00
# 776 Episode in 155200 steps, reward -200.00
# 777 Episode in 155400 steps, reward -200.00
# 778 Episode in 155600 steps, reward -200.00
# 779 Episode in 155800 steps, reward -200.00
# 780 Episode in 156000 steps, reward -200.00
# 781 Episode in 156200 steps, reward -200.00
# 782 Episode in 156400 steps, reward -200.00
# 783 Episode in 156600 steps, reward -200.00
# 784 Episode in 156800 steps, reward -200.00
# 785 Episode in 157000 steps, reward -200.00
# 786 Episode in 157200 steps, reward -200.00
# 787 Episode in 157400 steps, reward -200.00
# 788 Episode in 157600 steps, reward -200.00
# 789 Episode in 157800 steps, reward -200.00
# 790 Episode in 158000 steps, reward -200.00
# 791 Episode in 158200 steps, reward -200.00
# 792 Episode in 158400 steps, reward -200.00
# 793 Episode in 158600 steps, reward -200.00
# 794 Episode in 158800 steps, reward -200.00
# 795 Episode in 159000 steps, reward -200.00
# 796 Episode in 159200 steps, reward -200.00
# 797 Episode in 159400 steps, reward -200.00
# 798 Episode in 159600 steps, reward -200.00
# 799 Episode in 159800 steps, reward -200.00
# 800 Episode in 160000 steps, reward -200.00
# 801 Episode in 160200 steps, reward -200.00
# 802 Episode in 160400 steps, reward -200.00
# 803 Episode in 160600 steps, reward -200.00
# 804 Episode in 160800 steps, reward -200.00
# 805 Episode in 161000 steps, reward -200.00
# 806 Episode in 161200 steps, reward -200.00
# 807 Episode in 161400 steps, reward -200.00
# 808 Episode in 161600 steps, reward -200.00
# 809 Episode in 161800 steps, reward -200.00
# 810 Episode in 162000 steps, reward -200.00
# 811 Episode in 162200 steps, reward -200.00
# 812 Episode in 162400 steps, reward -200.00
# 813 Episode in 162600 steps, reward -200.00
# 814 Episode in 162800 steps, reward -200.00
# 815 Episode in 163000 steps, reward -200.00
# 816 Episode in 163200 steps, reward -200.00
# 817 Episode in 163400 steps, reward -200.00
# 818 Episode in 163600 steps, reward -200.00
# 819 Episode in 163800 steps, reward -200.00
# 820 Episode in 164000 steps, reward -200.00
# 821 Episode in 164200 steps, reward -200.00
# 822 Episode in 164400 steps, reward -200.00
# 823 Episode in 164600 steps, reward -200.00
# 824 Episode in 164800 steps, reward -200.00
# 825 Episode in 165000 steps, reward -200.00
# 826 Episode in 165200 steps, reward -200.00
# 827 Episode in 165400 steps, reward -200.00
# 828 Episode in 165600 steps, reward -200.00
# 829 Episode in 165800 steps, reward -200.00
# 830 Episode in 166000 steps, reward -200.00
# 831 Episode in 166200 steps, reward -200.00
# 832 Episode in 166400 steps, reward -200.00
# 833 Episode in 166600 steps, reward -200.00
# 834 Episode in 166800 steps, reward -200.00
# 835 Episode in 167000 steps, reward -200.00
# 836 Episode in 167200 steps, reward -200.00
# 837 Episode in 167400 steps, reward -200.00
# 838 Episode in 167600 steps, reward -200.00
# 839 Episode in 167800 steps, reward -200.00
# 840 Episode in 168000 steps, reward -200.00
# 841 Episode in 168200 steps, reward -200.00
# 842 Episode in 168400 steps, reward -200.00
# 843 Episode in 168600 steps, reward -200.00
# 844 Episode in 168800 steps, reward -200.00
# 845 Episode in 169000 steps, reward -200.00
# 846 Episode in 169200 steps, reward -200.00
# 847 Episode in 169400 steps, reward -200.00
# 848 Episode in 169600 steps, reward -200.00
# 849 Episode in 169800 steps, reward -200.00
# 850 Episode in 170000 steps, reward -200.00
# 851 Episode in 170200 steps, reward -200.00
# 852 Episode in 170400 steps, reward -200.00
# 853 Episode in 170600 steps, reward -200.00
# 854 Episode in 170800 steps, reward -200.00
# 855 Episode in 171000 steps, reward -200.00
# 856 Episode in 171200 steps, reward -200.00
# 857 Episode in 171400 steps, reward -200.00
# 858 Episode in 171600 steps, reward -200.00
# 859 Episode in 171800 steps, reward -200.00
# 860 Episode in 172000 steps, reward -200.00
# 861 Episode in 172200 steps, reward -200.00
# 862 Episode in 172400 steps, reward -200.00
# 863 Episode in 172600 steps, reward -200.00
# 864 Episode in 172800 steps, reward -200.00
# 865 Episode in 173000 steps, reward -200.00
# 866 Episode in 173200 steps, reward -200.00
# 867 Episode in 173400 steps, reward -200.00
# 868 Episode in 173600 steps, reward -200.00
# 869 Episode in 173800 steps, reward -200.00
# 870 Episode in 174000 steps, reward -200.00
# 871 Episode in 174200 steps, reward -200.00
# 872 Episode in 174400 steps, reward -200.00
# 873 Episode in 174600 steps, reward -200.00
# 874 Episode in 174800 steps, reward -200.00
# 875 Episode in 175000 steps, reward -200.00
# 876 Episode in 175200 steps, reward -200.00
# 877 Episode in 175400 steps, reward -200.00
# 878 Episode in 175600 steps, reward -200.00
# 879 Episode in 175800 steps, reward -200.00
# 880 Episode in 176000 steps, reward -200.00
# 881 Episode in 176200 steps, reward -200.00
# 882 Episode in 176400 steps, reward -200.00
# 883 Episode in 176600 steps, reward -200.00
# 884 Episode in 176800 steps, reward -200.00
# 885 Episode in 177000 steps, reward -200.00
# 886 Episode in 177200 steps, reward -200.00
# 887 Episode in 177400 steps, reward -200.00
# 888 Episode in 177600 steps, reward -200.00
# 889 Episode in 177800 steps, reward -200.00
# 890 Episode in 178000 steps, reward -200.00
# 891 Episode in 178200 steps, reward -200.00
# 892 Episode in 178400 steps, reward -200.00
# 893 Episode in 178600 steps, reward -200.00
# 894 Episode in 178800 steps, reward -200.00
# 895 Episode in 179000 steps, reward -200.00
# 896 Episode in 179200 steps, reward -200.00
# 897 Episode in 179400 steps, reward -200.00
# 898 Episode in 179600 steps, reward -200.00
# 899 Episode in 179800 steps, reward -200.00
# 900 Episode in 180000 steps, reward -200.00
# 901 Episode in 180200 steps, reward -200.00
# 902 Episode in 180400 steps, reward -200.00
# 903 Episode in 180600 steps, reward -200.00
# 904 Episode in 180800 steps, reward -200.00
# 905 Episode in 181000 steps, reward -200.00
# 906 Episode in 181200 steps, reward -200.00
# 907 Episode in 181400 steps, reward -200.00
# 908 Episode in 181600 steps, reward -200.00
# 909 Episode in 181800 steps, reward -200.00
# 910 Episode in 182000 steps, reward -200.00
# 911 Episode in 182200 steps, reward -200.00
# 912 Episode in 182400 steps, reward -200.00
# 913 Episode in 182600 steps, reward -200.00
# 914 Episode in 182800 steps, reward -200.00
# 915 Episode in 183000 steps, reward -200.00
# 916 Episode in 183200 steps, reward -200.00
# 917 Episode in 183400 steps, reward -200.00
# 918 Episode in 183600 steps, reward -200.00
# 919 Episode in 183800 steps, reward -200.00
# 920 Episode in 184000 steps, reward -200.00
# 921 Episode in 184200 steps, reward -200.00
# 922 Episode in 184400 steps, reward -200.00
# 923 Episode in 184600 steps, reward -200.00
# 924 Episode in 184800 steps, reward -200.00
# 925 Episode in 185000 steps, reward -200.00
# 926 Episode in 185200 steps, reward -200.00
# 927 Episode in 185400 steps, reward -200.00
# 928 Episode in 185600 steps, reward -200.00
# 929 Episode in 185800 steps, reward -200.00
# 930 Episode in 186000 steps, reward -200.00
# 931 Episode in 186200 steps, reward -200.00
# 932 Episode in 186400 steps, reward -200.00
# 933 Episode in 186600 steps, reward -200.00
# 934 Episode in 186800 steps, reward -200.00
# 935 Episode in 187000 steps, reward -200.00
# 936 Episode in 187200 steps, reward -200.00
# 937 Episode in 187400 steps, reward -200.00
# 938 Episode in 187600 steps, reward -200.00
# 939 Episode in 187800 steps, reward -200.00
# 940 Episode in 188000 steps, reward -200.00
# 941 Episode in 188200 steps, reward -200.00
# 942 Episode in 188400 steps, reward -200.00
# 943 Episode in 188600 steps, reward -200.00
# 944 Episode in 188800 steps, reward -200.00
# 945 Episode in 189000 steps, reward -200.00
# 946 Episode in 189200 steps, reward -200.00
# 947 Episode in 189400 steps, reward -200.00
# 948 Episode in 189600 steps, reward -200.00
# 949 Episode in 189800 steps, reward -200.00
# 950 Episode in 190000 steps, reward -200.00
# 951 Episode in 190200 steps, reward -200.00
# 952 Episode in 190400 steps, reward -200.00
# 953 Episode in 190600 steps, reward -200.00
# 954 Episode in 190800 steps, reward -200.00
# 955 Episode in 191000 steps, reward -200.00
# 956 Episode in 191200 steps, reward -200.00
# 957 Episode in 191400 steps, reward -200.00
# 958 Episode in 191600 steps, reward -200.00
# 959 Episode in 191800 steps, reward -200.00
# 960 Episode in 192000 steps, reward -200.00
# 961 Episode in 192200 steps, reward -200.00
# 962 Episode in 192400 steps, reward -200.00
# 963 Episode in 192600 steps, reward -200.00
# 964 Episode in 192800 steps, reward -200.00
# 965 Episode in 193000 steps, reward -200.00
# 966 Episode in 193200 steps, reward -200.00
# 967 Episode in 193400 steps, reward -200.00
# 968 Episode in 193600 steps, reward -200.00
# 969 Episode in 193800 steps, reward -200.00
# 970 Episode in 194000 steps, reward -200.00
# 971 Episode in 194200 steps, reward -200.00
# 972 Episode in 194400 steps, reward -200.00

# %%
plt.figure(figsize=(15, 5))
plt.title('Reward')
plt.plot(ep_rewards)
plt.figure(figsize=(15, 5))
plt.title('Loss')
plt.plot(losses)
plt.show()

# %%
[
    ('CartPole-v0', 692, 4, 128),
    ('CartPole-v1', 525, 4, 128),
    ('MountainCar-v0', 660),
    ('LunarLander-v2', 260)
]
